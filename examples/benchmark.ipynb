# %% [markdown]
# # Reproducing or downloading the benchmark results and running new configurations on the benchmark

# %% [markdown]
# ## Reproducing or downloading our results

# %% [markdown]
# In this notebook, we discuss how to reproduce the results from our paper and how to benchmark your own methods. Before running this notebook, please follow the installation and data download instructions from the README.md file of the repository.

# %% [markdown]
# We will now change the working directory from the examples subfolder to the main folder, which is required for the imports to work correctly.

# %%
import os
os.chdir('..')   # change directory inside the notebook to the main directory

# %% [markdown]
# Our benchmark results can be generated using the file `run_experiments.py`. This takes around six days on a workstation with four NVIDIA GeForce RTX 3090 GPUs! In order to use our pre-computed results, download the file `results.tar.gz` which will be published [here](https://doi.org/10.18419/darus-2615) and unpack its contents into the results folder you specified in `custom_paths.py`.
#
# If you want to run `run_experiments.py` yourself, for example because you modified it to run your own benchmark configurations, you can for example execute the following command in the main folder:
# ```
# systemd-run --scope --user python3 -u run_experiments.py > ./out.log 2> ./err.log &
# ```
# This command writes the output and error messages to the files `out.log` and `err.log`, respectively. A lot of output will be generated, so this is definitely a good idea. You can monitor the progress of the experiments for example by using the following commands:
# ```
# watch 'cat out.log | grep Running | tail -n 30'
# watch 'cat out.log | grep Finished | tail -n 30'
# watch 'cat out.log | grep time | tail -n 30'
# ```
#
# Note that `run_experiments.py` will use all visible GPUs as devices or, if no GPU is visible, it will use the CPU as the only device. It will try to run multiple configurations in parallel, but it will try to not exceed the available RAM on the devices, and it will run at most 20 jobs per device at the same time. Note that the available RAM is measured only at the start of each new data split, so no other jobs with strongly varying RAM demand should run in parallel. Once a configuration has finished running, its results are saved. On a GPU, a configuration takes only a few minutes to run. If you kill `run_experiments.py` and restart it, finished jobs will not be run again, hence it is not very bad to kill `run_experiments.py`. Note that split 9 takes longer to run since it runs only one process per GPU.

# %% [markdown]
# After generating or downloading the result files, we can print and save tables summarizing the results and generate corresponding plots using `run_evaluation.py`. This might take a few minutes for the results from the paper, as these contain data for around 900.000 trained NNs! Note that some of the plot configurations are tailored towards our specific results and might need to be changed if you want to plot your own results. The generated files will be saved in the plots folder that has been configured in `custom_paths.py`. If you are only interested in the generated files, these will also be published [here](https://doi.org/10.18419/darus-2615) in the file `plots.tar.gz`.

# %%
# !python3 run_evaluation.py
# Out:
# ----- Running evaluation for relu experiments -----
# Loading experiment results...
# Loaded experiment results
# Averaged results across tasks:
# Results for metric mae:
# NN_lcmd-tp_grad_ens-3_rp-512:               -2.036 +- 0.001
# NN_lcmd-tp_grad:                            -2.033 +- 0.001
# NN_lcmd-tp_grad_rp-512:                     -2.029 +- 0.001
# NN_kmeanspp-tp_grad_ens-3_rp-512:           -2.023 +- 0.001
# NN_kmeanspp-tp_grad_rp-512:                 -2.022 +- 0.001
# NN_kmeanspp-tp_grad:                        -2.021 +- 0.001
# NN_lcmd-tp_ll_ens-3_rp-512:                 -2.021 +- 0.001
# NN_kmeanspp-p_grad_rp-512_train:            -2.017 +- 0.001
# NN_kmeanspp-tp_ll_ens-3_rp-512:             -2.016 +- 0.001
# NN_lcmd-tp_ll:                              -2.013 +- 0.002
# NN_kmeanspp-tp_ll:                          -2.011 +- 0.002
# NN_kmeanspp-p_ll_train:                     -2.005 +- 0.001
# NN_kmeanspp-p_grad_rp-512_acs-rf-512:       -2.005 +- 0.001
# NN_kmeanspp-p_grad_rp-512_acs-grad:         -2.002 +- 0.001
# NN_fw-p_grad_rp-512_acs-rf-512:             -1.998 +- 0.002
# NN_kmeanspp-p_ll_acs-rf-512:                -1.998 +- 0.001
# NN_fw-p_ll_acs-rf-512:                      -1.997 +- 0.002
# NN_fw-p_grad_rp-512_acs-grad_rp-512:        -1.995 +- 0.001
# NN_kmeanspp-p_grad_rp-512_acs-rf-hyper-512: -1.992 +- 0.001
# NN_lcmd-p_grad_rp-512_acs-rf-512:           -1.986 +- 0.001
# NN_fw-p_grad_rp-512_acs-rf-hyper-512:       -1.976 +- 0.001
# NN_lcmd-p_ll_acs-rf-512:                    -1.972 +- 0.002
# NN_kmeanspp-tp_nngp:                        -1.966 +- 0.001
# NN_kmeanspp-tp_linear:                      -1.966 +- 0.002
# NN_lcmd-tp_nngp:                            -1.956 +- 0.002
# NN_lcmd-tp_linear:                          -1.955 +- 0.002
# NN_maxdist-tp_ll_ens-3_rp-512:              -1.941 +- 0.002
# NN_fw-p_ll_acs-rf-hyper-512:                -1.935 +- 0.002
# NN_lcmd-p_ll_train:                         -1.934 +- 0.002
# NN_random:                                  -1.933 +- 0.002
# NN_fw-p_ll_acs-grad_rp-512:                 -1.933 +- 0.002
# NN_lcmd-p_grad_rp-512_train:                -1.930 +- 0.002
# NN_maxdet-tp_grad_scale:                    -1.929 +- 0.002
# NN_maxdist-tp_ll:                           -1.922 +- 0.003
# NN_fw-p_grad_rp-512_train:                  -1.917 +- 0.002
# NN_maxdet-p_ll_ens-3_rp-512_train:          -1.915 +- 0.002
# NN_maxdist-p_grad_rp-512_train:             -1.910 +- 0.002
# NN_maxdet-p_grad_rp-512_train:              -1.905 +- 0.002
# NN_maxdist-p_ll_train:                      -1.898 +- 0.003
# NN_lcmd-p_grad_rp-512_acs-rf-hyper-512:     -1.895 +- 0.002
# NN_maxdist-tp_grad:                         -1.895 +- 0.002
# NN_maxdist-tp_grad_rp-512:                  -1.893 +- 0.002
# NN_maxdet-p_grad_rp-512_acs-rf-512:         -1.891 +- 0.002
# NN_lcmd-p_grad_rp-512_acs-grad:             -1.890 +- 0.002
# NN_maxdist-p_grad_rp-512_acs-rf-512:        -1.887 +- 0.002
# NN_maxdet-p_grad_ens-3_rp-512_train:        -1.886 +- 0.002
# NN_maxdet-p_ll_train:                       -1.886 +- 0.002
# NN_maxdist-tp_grad_ens-3_rp-512:            -1.884 +- 0.002
# NN_maxdist-tp_linear:                       -1.884 +- 0.002
# NN_maxdet-p_ll_acs-rf-512:                  -1.880 +- 0.003
# NN_fw-p_ll_train:                           -1.880 +- 0.002
# NN_maxdist-p_ll_acs-rf-512:                 -1.874 +- 0.003
# NN_maxdist-tp_nngp:                         -1.870 +- 0.002
# NN_maxdist-p_grad_rp-512_acs-grad:          -1.870 +- 0.002
# NN_maxdet-p_grad_rp-512_acs-grad:           -1.866 +- 0.002
# NN_maxdet-p_grad_rp-512_acs-rf-hyper-512:   -1.865 +- 0.002
# NN_maxdist-p_grad_rp-512_acs-rf-hyper-512:  -1.862 +- 0.002
# NN_maxdet-tp_nngp_scale:                    -1.845 +- 0.002
# NN_maxdiag_grad_rp-512_acs-rf-512:          -1.772 +- 0.002
# NN_maxdiag_grad_rp-512_train:               -1.771 +- 0.002
# NN_maxdiag_grad_train:                      -1.770 +- 0.003
# NN_maxdiag_grad_ens-3_rp-512_train:         -1.759 +- 0.003
# NN_maxdiag_nngp_train:                      -1.756 +- 0.002
# NN_maxdiag_grad_rp-512_acs-grad:            -1.748 +- 0.003
# NN_maxdiag_grad_rp-512_acs-rf-hyper-512:    -1.738 +- 0.003
# NN_maxdiag_ll_acs-rf-512:                   -1.725 +- 0.003
# NN_maxdiag_ll_train:                        -1.725 +- 0.004
# NN_maxdet-p_linear_train:                   -1.684 +- 0.002
# NN_maxdiag_linear_train:                    -1.595 +- 0.003
#
# Results for metric rmse:
# NN_lcmd-tp_grad_ens-3_rp-512:               -1.590 +- 0.002
# NN_lcmd-tp_grad:                            -1.587 +- 0.002
# NN_lcmd-tp_grad_rp-512:                     -1.584 +- 0.002
# NN_kmeanspp-p_grad_rp-512_acs-rf-512:       -1.566 +- 0.002
# NN_kmeanspp-tp_grad_rp-512:                 -1.564 +- 0.002
# NN_kmeanspp-tp_grad_ens-3_rp-512:           -1.564 +- 0.002
# NN_kmeanspp-tp_grad:                        -1.563 +- 0.002
# NN_kmeanspp-p_grad_rp-512_acs-rf-hyper-512: -1.551 +- 0.002
# NN_lcmd-tp_ll_ens-3_rp-512:                 -1.550 +- 0.002
# NN_kmeanspp-p_grad_rp-512_acs-grad:         -1.550 +- 0.002
# NN_lcmd-p_grad_rp-512_acs-rf-512:           -1.543 +- 0.002
# NN_kmeanspp-p_grad_rp-512_train:            -1.541 +- 0.002
# NN_fw-p_grad_rp-512_acs-rf-hyper-512:       -1.540 +- 0.002
# NN_lcmd-tp_ll:                              -1.538 +- 0.003
# NN_kmeanspp-p_ll_acs-rf-512:                -1.531 +- 0.002
# NN_lcmd-p_grad_rp-512_train:                -1.525 +- 0.002
# NN_maxdet-tp_grad_scale:                    -1.520 +- 0.002
# NN_kmeanspp-tp_ll:                          -1.518 +- 0.002
# NN_kmeanspp-tp_ll_ens-3_rp-512:             -1.517 +- 0.002
# NN_kmeanspp-p_ll_train:                     -1.515 +- 0.002
# NN_fw-p_grad_rp-512_acs-grad_rp-512:        -1.514 +- 0.002
# NN_maxdist-tp_ll_ens-3_rp-512:              -1.511 +- 0.002
# NN_fw-p_ll_acs-rf-512:                      -1.510 +- 0.002
# NN_maxdist-p_grad_rp-512_train:             -1.510 +- 0.002
# NN_maxdet-p_grad_rp-512_train:              -1.504 +- 0.002
# NN_lcmd-p_ll_acs-rf-512:                    -1.504 +- 0.003
# NN_fw-p_grad_rp-512_acs-rf-512:             -1.504 +- 0.002
# NN_maxdist-tp_grad:                         -1.501 +- 0.002
# NN_maxdist-tp_grad_rp-512:                  -1.501 +- 0.002
# NN_lcmd-p_grad_rp-512_acs-rf-hyper-512:     -1.498 +- 0.002
# NN_maxdist-tp_grad_ens-3_rp-512:            -1.495 +- 0.002
# NN_maxdet-p_grad_ens-3_rp-512_train:        -1.494 +- 0.002
# NN_lcmd-p_grad_rp-512_acs-grad:             -1.493 +- 0.002
# NN_lcmd-p_ll_train:                         -1.492 +- 0.002
# NN_maxdet-p_grad_rp-512_acs-rf-512:         -1.490 +- 0.002
# NN_maxdist-p_grad_rp-512_acs-rf-512:        -1.486 +- 0.002
# NN_maxdist-tp_ll:                           -1.486 +- 0.003
# NN_maxdet-p_ll_ens-3_rp-512_train:          -1.485 +- 0.002
# NN_maxdist-p_grad_rp-512_acs-grad:          -1.473 +- 0.002
# NN_maxdet-p_grad_rp-512_acs-grad:           -1.471 +- 0.002
# NN_maxdet-p_grad_rp-512_acs-rf-hyper-512:   -1.470 +- 0.002
# NN_maxdist-p_grad_rp-512_acs-rf-hyper-512:  -1.469 +- 0.002
# NN_maxdist-p_ll_train:                      -1.468 +- 0.003
# NN_maxdet-p_ll_train:                       -1.451 +- 0.002
# NN_maxdet-p_ll_acs-rf-512:                  -1.450 +- 0.003
# NN_lcmd-tp_nngp:                            -1.445 +- 0.002
# NN_lcmd-tp_linear:                          -1.444 +- 0.003
# NN_kmeanspp-tp_linear:                      -1.442 +- 0.002
# NN_kmeanspp-tp_nngp:                        -1.442 +- 0.002
# NN_maxdist-p_ll_acs-rf-512:                 -1.438 +- 0.004
# NN_fw-p_ll_acs-rf-hyper-512:                -1.435 +- 0.002
# NN_fw-p_ll_acs-grad_rp-512:                 -1.426 +- 0.002
# NN_fw-p_grad_rp-512_train:                  -1.401 +- 0.002
# NN_random:                                  -1.399 +- 0.002
# NN_maxdist-tp_linear:                       -1.395 +- 0.002
# NN_maxdist-tp_nngp:                         -1.382 +- 0.002
# NN_maxdiag_grad_rp-512_acs-rf-512:          -1.367 +- 0.002
# NN_maxdiag_grad_rp-512_train:               -1.365 +- 0.002
# NN_fw-p_ll_train:                           -1.364 +- 0.002
# NN_maxdiag_grad_train:                      -1.360 +- 0.003
# NN_maxdiag_grad_ens-3_rp-512_train:         -1.359 +- 0.002
# NN_maxdet-tp_nngp_scale:                    -1.357 +- 0.002
# NN_maxdiag_grad_rp-512_acs-grad:            -1.343 +- 0.002
# NN_maxdiag_grad_rp-512_acs-rf-hyper-512:    -1.330 +- 0.003
# NN_maxdiag_ll_acs-rf-512:                   -1.300 +- 0.003
# NN_maxdiag_ll_train:                        -1.285 +- 0.005
# NN_maxdiag_nngp_train:                      -1.273 +- 0.002
# NN_maxdet-p_linear_train:                   -1.190 +- 0.003
# NN_maxdiag_linear_train:                    -1.110 +- 0.003
#
# Results for metric q95:
# NN_lcmd-tp_grad_ens-3_rp-512:               -0.944 +- 0.002
# NN_lcmd-tp_grad:                            -0.941 +- 0.002
# NN_lcmd-tp_grad_rp-512:                     -0.936 +- 0.001
# NN_kmeanspp-tp_grad_rp-512:                 -0.925 +- 0.001
# NN_kmeanspp-tp_grad_ens-3_rp-512:           -0.924 +- 0.001
# NN_kmeanspp-tp_grad:                        -0.923 +- 0.001
# NN_kmeanspp-p_grad_rp-512_acs-rf-512:       -0.911 +- 0.001
# NN_lcmd-tp_ll_ens-3_rp-512:                 -0.908 +- 0.002
# NN_kmeanspp-p_grad_rp-512_train:            -0.902 +- 0.001
# NN_lcmd-p_grad_rp-512_acs-rf-512:           -0.900 +- 0.002
# NN_lcmd-tp_ll:                              -0.900 +- 0.002
# NN_kmeanspp-p_grad_rp-512_acs-grad:         -0.898 +- 0.001
# NN_kmeanspp-p_grad_rp-512_acs-rf-hyper-512: -0.897 +- 0.001
# NN_kmeanspp-p_ll_acs-rf-512:                -0.895 +- 0.002
# NN_fw-p_grad_rp-512_acs-rf-hyper-512:       -0.889 +- 0.001
# NN_kmeanspp-tp_ll:                          -0.885 +- 0.002
# NN_kmeanspp-tp_ll_ens-3_rp-512:             -0.883 +- 0.002
# NN_kmeanspp-p_ll_train:                     -0.881 +- 0.002
# NN_fw-p_ll_acs-rf-512:                      -0.876 +- 0.001
# NN_fw-p_grad_rp-512_acs-grad_rp-512:        -0.874 +- 0.001
# NN_lcmd-p_ll_acs-rf-512:                    -0.872 +- 0.002
# NN_fw-p_grad_rp-512_acs-rf-512:             -0.867 +- 0.002
# NN_lcmd-p_grad_rp-512_train:                -0.862 +- 0.002
# NN_maxdet-tp_grad_scale:                    -0.855 +- 0.002
# NN_maxdist-tp_ll_ens-3_rp-512:              -0.854 +- 0.002
# NN_lcmd-p_ll_train:                         -0.847 +- 0.002
# NN_maxdist-p_grad_rp-512_train:             -0.842 +- 0.002
# NN_maxdet-p_grad_rp-512_train:              -0.834 +- 0.002
# NN_maxdist-tp_grad:                         -0.834 +- 0.002
# NN_maxdist-tp_grad_rp-512:                  -0.832 +- 0.002
# NN_maxdet-p_ll_ens-3_rp-512_train:          -0.831 +- 0.002
# NN_maxdist-tp_ll:                           -0.830 +- 0.003
# NN_maxdist-tp_grad_ens-3_rp-512:            -0.826 +- 0.002
# NN_lcmd-p_grad_rp-512_acs-rf-hyper-512:     -0.826 +- 0.002
# NN_lcmd-p_grad_rp-512_acs-grad:             -0.822 +- 0.002
# NN_maxdet-p_grad_ens-3_rp-512_train:        -0.822 +- 0.002
# NN_maxdet-p_grad_rp-512_acs-rf-512:         -0.819 +- 0.002
# NN_kmeanspp-tp_linear:                      -0.816 +- 0.001
# NN_maxdist-p_grad_rp-512_acs-rf-512:        -0.814 +- 0.002
# NN_maxdist-p_ll_train:                      -0.814 +- 0.003
# NN_kmeanspp-tp_nngp:                        -0.814 +- 0.002
# NN_lcmd-tp_nngp:                            -0.808 +- 0.002
# NN_lcmd-tp_linear:                          -0.807 +- 0.002
# NN_maxdist-p_grad_rp-512_acs-grad:          -0.800 +- 0.002
# NN_maxdet-p_grad_rp-512_acs-grad:           -0.797 +- 0.002
# NN_maxdet-p_ll_train:                       -0.797 +- 0.002
# NN_maxdet-p_grad_rp-512_acs-rf-hyper-512:   -0.796 +- 0.002
# NN_maxdet-p_ll_acs-rf-512:                  -0.795 +- 0.003
# NN_maxdist-p_grad_rp-512_acs-rf-hyper-512:  -0.795 +- 0.002
# NN_fw-p_ll_acs-rf-hyper-512:                -0.792 +- 0.002
# NN_fw-p_ll_acs-grad_rp-512:                 -0.788 +- 0.002
# NN_maxdist-p_ll_acs-rf-512:                 -0.787 +- 0.003
# NN_random:                                  -0.764 +- 0.002
# NN_fw-p_grad_rp-512_train:                  -0.757 +- 0.002
# NN_maxdist-tp_linear:                       -0.746 +- 0.002
# NN_maxdist-tp_nngp:                         -0.730 +- 0.002
# NN_fw-p_ll_train:                           -0.729 +- 0.002
# NN_maxdet-tp_nngp_scale:                    -0.700 +- 0.002
# NN_maxdiag_grad_rp-512_acs-rf-512:          -0.687 +- 0.002
# NN_maxdiag_grad_rp-512_train:               -0.684 +- 0.002
# NN_maxdiag_grad_train:                      -0.679 +- 0.003
# NN_maxdiag_grad_ens-3_rp-512_train:         -0.677 +- 0.003
# NN_maxdiag_grad_rp-512_acs-grad:            -0.661 +- 0.003
# NN_maxdiag_grad_rp-512_acs-rf-hyper-512:    -0.652 +- 0.003
# NN_maxdiag_ll_acs-rf-512:                   -0.626 +- 0.003
# NN_maxdiag_ll_train:                        -0.619 +- 0.004
# NN_maxdiag_nngp_train:                      -0.608 +- 0.002
# NN_maxdet-p_linear_train:                   -0.527 +- 0.003
# NN_maxdiag_linear_train:                    -0.437 +- 0.003
#
# Results for metric q99:
# NN_lcmd-tp_grad_ens-3_rp-512:               -0.405 +- 0.002
# NN_lcmd-tp_grad:                            -0.404 +- 0.002
# NN_lcmd-tp_grad_rp-512:                     -0.398 +- 0.002
# NN_kmeanspp-p_grad_rp-512_acs-rf-512:       -0.383 +- 0.002
# NN_kmeanspp-tp_grad_ens-3_rp-512:           -0.375 +- 0.001
# NN_kmeanspp-tp_grad_rp-512:                 -0.374 +- 0.002
# NN_kmeanspp-tp_grad:                        -0.373 +- 0.002
# NN_kmeanspp-p_grad_rp-512_acs-rf-hyper-512: -0.368 +- 0.002
# NN_lcmd-p_grad_rp-512_acs-rf-512:           -0.366 +- 0.002
# NN_lcmd-p_grad_rp-512_train:                -0.364 +- 0.002
# NN_kmeanspp-p_grad_rp-512_acs-grad:         -0.360 +- 0.002
# NN_fw-p_grad_rp-512_acs-rf-hyper-512:       -0.359 +- 0.002
# NN_maxdet-tp_grad_scale:                    -0.356 +- 0.003
# NN_lcmd-tp_ll_ens-3_rp-512:                 -0.353 +- 0.002
# NN_maxdist-p_grad_rp-512_train:             -0.350 +- 0.002
# NN_maxdist-tp_grad:                         -0.344 +- 0.002
# NN_kmeanspp-p_ll_acs-rf-512:                -0.344 +- 0.002
# NN_lcmd-tp_ll:                              -0.343 +- 0.002
# NN_kmeanspp-p_grad_rp-512_train:            -0.342 +- 0.002
# NN_maxdist-tp_grad_rp-512:                  -0.341 +- 0.002
# NN_maxdet-p_grad_rp-512_train:              -0.340 +- 0.002
# NN_maxdist-tp_ll_ens-3_rp-512:              -0.338 +- 0.002
# NN_maxdist-tp_grad_ens-3_rp-512:            -0.337 +- 0.003
# NN_maxdet-p_grad_ens-3_rp-512_train:        -0.336 +- 0.002
# NN_lcmd-p_grad_rp-512_acs-rf-hyper-512:     -0.334 +- 0.002
# NN_lcmd-p_grad_rp-512_acs-grad:             -0.332 +- 0.002
# NN_maxdet-p_grad_rp-512_acs-rf-512:         -0.323 +- 0.003
# NN_lcmd-p_ll_train:                         -0.319 +- 0.002
# NN_maxdet-p_ll_ens-3_rp-512_train:          -0.319 +- 0.003
# NN_maxdist-p_grad_rp-512_acs-rf-512:        -0.317 +- 0.002
# NN_lcmd-p_ll_acs-rf-512:                    -0.315 +- 0.003
# NN_kmeanspp-tp_ll:                          -0.312 +- 0.002
# NN_kmeanspp-tp_ll_ens-3_rp-512:             -0.311 +- 0.002
# NN_kmeanspp-p_ll_train:                     -0.310 +- 0.002
# NN_fw-p_grad_rp-512_acs-grad_rp-512:        -0.310 +- 0.002
# NN_maxdist-p_grad_rp-512_acs-grad:          -0.310 +- 0.003
# NN_maxdet-p_grad_rp-512_acs-grad:           -0.308 +- 0.003
# NN_fw-p_ll_acs-rf-512:                      -0.308 +- 0.002
# NN_maxdet-p_grad_rp-512_acs-rf-hyper-512:   -0.306 +- 0.003
# NN_maxdist-p_grad_rp-512_acs-rf-hyper-512:  -0.303 +- 0.002
# NN_maxdist-tp_ll:                           -0.303 +- 0.004
# NN_maxdist-p_ll_train:                      -0.295 +- 0.004
# NN_fw-p_grad_rp-512_acs-rf-512:             -0.292 +- 0.002
# NN_maxdet-p_ll_train:                       -0.276 +- 0.003
# NN_maxdet-p_ll_acs-rf-512:                  -0.268 +- 0.004
# NN_maxdist-p_ll_acs-rf-512:                 -0.253 +- 0.005
# NN_fw-p_ll_acs-rf-hyper-512:                -0.220 +- 0.002
# NN_lcmd-tp_nngp:                            -0.214 +- 0.003
# NN_lcmd-tp_linear:                          -0.213 +- 0.003
# NN_kmeanspp-tp_nngp:                        -0.212 +- 0.002
# NN_kmeanspp-tp_linear:                      -0.211 +- 0.002
# NN_fw-p_ll_acs-grad_rp-512:                 -0.201 +- 0.002
# NN_maxdiag_grad_rp-512_acs-rf-512:          -0.186 +- 0.003
# NN_maxdiag_grad_rp-512_train:               -0.183 +- 0.003
# NN_maxdiag_grad_ens-3_rp-512_train:         -0.182 +- 0.003
# NN_maxdiag_grad_train:                      -0.174 +- 0.003
# NN_fw-p_grad_rp-512_train:                  -0.168 +- 0.002
# NN_maxdist-tp_linear:                       -0.167 +- 0.003
# NN_maxdiag_grad_rp-512_acs-grad:            -0.162 +- 0.003
# NN_random:                                  -0.161 +- 0.002
# NN_maxdist-tp_nngp:                         -0.152 +- 0.003
# NN_maxdiag_grad_rp-512_acs-rf-hyper-512:    -0.145 +- 0.003
# NN_maxdet-tp_nngp_scale:                    -0.132 +- 0.003
# NN_fw-p_ll_train:                           -0.124 +- 0.003
# NN_maxdiag_ll_acs-rf-512:                   -0.103 +- 0.004
# NN_maxdiag_ll_train:                        -0.075 +- 0.006
# NN_maxdiag_nngp_train:                      -0.046 +- 0.003
# NN_maxdet-p_linear_train:                   0.053  +- 0.004
# NN_maxdiag_linear_train:                    0.138  +- 0.004
#
# Results for metric maxe:
# NN_maxdet-tp_grad_scale:                    0.862 +- 0.009
# NN_maxdet-p_grad_ens-3_rp-512_train:        0.865 +- 0.010
# NN_maxdist-p_grad_rp-512_train:             0.869 +- 0.009
# NN_maxdist-tp_grad_rp-512:                  0.870 +- 0.009
# NN_maxdet-p_grad_rp-512_train:              0.871 +- 0.009
# NN_lcmd-p_grad_rp-512_train:                0.871 +- 0.009
# NN_maxdist-tp_grad:                         0.873 +- 0.010
# NN_maxdist-tp_grad_ens-3_rp-512:            0.877 +- 0.009
# NN_lcmd-p_grad_rp-512_acs-grad:             0.883 +- 0.010
# NN_maxdet-p_ll_ens-3_rp-512_train:          0.884 +- 0.008
# NN_lcmd-p_grad_rp-512_acs-rf-hyper-512:     0.886 +- 0.009
# NN_maxdet-p_grad_rp-512_acs-rf-512:         0.889 +- 0.009
# NN_maxdet-p_grad_rp-512_acs-grad:           0.892 +- 0.009
# NN_maxdet-p_grad_rp-512_acs-rf-hyper-512:   0.893 +- 0.009
# NN_maxdist-p_grad_rp-512_acs-rf-512:        0.893 +- 0.009
# NN_maxdist-p_grad_rp-512_acs-grad:          0.894 +- 0.009
# NN_maxdist-p_grad_rp-512_acs-rf-hyper-512:  0.900 +- 0.009
# NN_maxdist-tp_ll_ens-3_rp-512:              0.906 +- 0.009
# NN_maxdist-p_ll_train:                      0.919 +- 0.009
# NN_lcmd-tp_grad_rp-512:                     0.919 +- 0.009
# NN_lcmd-tp_grad:                            0.920 +- 0.008
# NN_maxdet-p_ll_train:                       0.921 +- 0.008
# NN_fw-p_grad_rp-512_acs-rf-hyper-512:       0.927 +- 0.008
# NN_kmeanspp-p_grad_rp-512_acs-rf-512:       0.930 +- 0.009
# NN_lcmd-tp_grad_ens-3_rp-512:               0.931 +- 0.009
# NN_lcmd-p_ll_train:                         0.931 +- 0.008
# NN_maxdist-tp_ll:                           0.936 +- 0.010
# NN_maxdet-p_ll_acs-rf-512:                  0.940 +- 0.010
# NN_lcmd-tp_ll_ens-3_rp-512:                 0.943 +- 0.007
# NN_kmeanspp-p_grad_rp-512_acs-rf-hyper-512: 0.959 +- 0.010
# NN_maxdist-p_ll_acs-rf-512:                 0.960 +- 0.010
# NN_lcmd-tp_ll:                              0.969 +- 0.008
# NN_kmeanspp-tp_grad:                        0.969 +- 0.008
# NN_lcmd-p_grad_rp-512_acs-rf-512:           0.971 +- 0.010
# NN_kmeanspp-tp_grad_rp-512:                 0.975 +- 0.009
# NN_kmeanspp-p_grad_rp-512_acs-grad:         0.980 +- 0.009
# NN_kmeanspp-tp_grad_ens-3_rp-512:           0.980 +- 0.008
# NN_maxdiag_grad_ens-3_rp-512_train:         0.982 +- 0.008
# NN_kmeanspp-p_ll_acs-rf-512:                0.986 +- 0.009
# NN_maxdiag_grad_rp-512_acs-rf-512:          0.988 +- 0.008
# NN_maxdiag_grad_rp-512_train:               0.988 +- 0.008
# NN_maxdiag_grad_train:                      0.997 +- 0.008
# NN_maxdiag_grad_rp-512_acs-grad:            1.005 +- 0.008
# NN_kmeanspp-p_grad_rp-512_train:            1.010 +- 0.009
# NN_kmeanspp-tp_ll:                          1.012 +- 0.008
# NN_kmeanspp-tp_ll_ens-3_rp-512:             1.016 +- 0.008
# NN_maxdiag_grad_rp-512_acs-rf-hyper-512:    1.027 +- 0.009
# NN_maxdet-tp_nngp_scale:                    1.028 +- 0.006
# NN_fw-p_ll_acs-rf-512:                      1.028 +- 0.008
# NN_fw-p_ll_acs-rf-hyper-512:                1.030 +- 0.007
# NN_fw-p_grad_rp-512_acs-grad_rp-512:        1.033 +- 0.009
# NN_lcmd-p_ll_acs-rf-512:                    1.033 +- 0.008
# NN_kmeanspp-p_ll_train:                     1.035 +- 0.008
# NN_maxdiag_ll_acs-rf-512:                   1.035 +- 0.007
# NN_maxdist-tp_nngp:                         1.038 +- 0.006
# NN_maxdist-tp_linear:                       1.039 +- 0.006
# NN_lcmd-tp_linear:                          1.043 +- 0.006
# NN_lcmd-tp_nngp:                            1.046 +- 0.006
# NN_fw-p_grad_rp-512_acs-rf-512:             1.052 +- 0.008
# NN_maxdiag_ll_train:                        1.068 +- 0.008
# NN_kmeanspp-tp_linear:                      1.080 +- 0.007
# NN_kmeanspp-tp_nngp:                        1.086 +- 0.007
# NN_maxdiag_nngp_train:                      1.089 +- 0.006
# NN_random:                                  1.111 +- 0.006
# NN_fw-p_ll_acs-grad_rp-512:                 1.115 +- 0.007
# NN_fw-p_grad_rp-512_train:                  1.134 +- 0.008
# NN_fw-p_ll_train:                           1.174 +- 0.007
# NN_maxdet-p_linear_train:                   1.189 +- 0.006
# NN_maxdiag_linear_train:                    1.218 +- 0.005
#
#
#
#
# Analyzing results
# eff dim was larger for grad_rp-512 than for ll in 94.9653% of cases
# avg eff dim for grad_rp-512: 5.48869
# avg eff dim for ll: 1.65612
# Alg NN_lcmd-tp_grad_rp-512 failed on step 40 of split 1 of task poker_64x64: filling up with random samples because selection failed after n_selected = 1
# Alg NN_lcmd-tp_grad_rp-512 failed on step 40 of split 14 of task poker_64x64: filling up with random samples because selection failed after n_selected = 1
# Alg NN_lcmd-tp_grad_rp-512 failed on step 13 of split 6 of task poker_256x16: filling up with random samples because selection failed after n_selected = 6
# Alg NN_kmeanspp-p_grad_rp-512_acs-rf-512 failed on step 23 of split 11 of task poker_128x32: filling up with random samples because selection failed after n_selected = 58
# Alg NN_kmeanspp-p_grad_rp-512_acs-rf-512 failed on step 29 of split 11 of task poker_128x32: filling up with random samples because selection failed after n_selected = 1
# Alg NN_kmeanspp-p_grad_rp-512_acs-rf-512 failed on step 45 of split 4 of task poker_64x64: filling up with random samples because selection failed after n_selected = 1
# Alg NN_kmeanspp-p_grad_rp-512_acs-rf-512 failed on step 0 of split 19 of task kegg_undir_uci_2048x2: filling up with random samples because selection failed after n_selected = 2043
# Alg NN_kmeanspp-p_grad_rp-512_acs-rf-512 failed on step 3 of split 6 of task poker_1024x4: filling up with random samples because selection failed after n_selected = 1
# Alg NN_kmeanspp-p_grad_rp-512_acs-rf-512 failed on step 0 of split 19 of task kegg_undir_uci_4096x1: filling up with random samples because selection failed after n_selected = 2043
# Alg NN_lcmd-tp_grad failed on step 12 of split 18 of task poker_256x16: filling up with random samples because selection failed after n_selected = 1
# Alg NN_maxdet-p_ll_acs-rf-512 failed on step 2 of split 1 of task poker_256x16: filling up with random samples because selection failed after n_selected = 174
# Alg NN_kmeanspp-p_ll_train failed on step 15 of split 17 of task poker_256x16: filling up with random samples because selection failed after n_selected = 4
# Alg NN_maxdist-p_grad_rp-512_acs-rf-hyper-512 failed on step 3 of split 9 of task poker_256x16: filling up with random samples because selection failed after n_selected = 124
# Alg NN_lcmd-p_grad_rp-512_train failed on step 7 of split 14 of task poker_256x16: filling up with random samples because selection failed after n_selected = 2
# Alg NN_lcmd-p_grad_rp-512_acs-rf-hyper-512 failed on step 2 of split 4 of task poker_256x16: filling up with random samples because selection failed after n_selected = 62
# Alg NN_lcmd-p_grad_rp-512_acs-rf-hyper-512 failed on step 4 of split 4 of task poker_256x16: filling up with random samples because selection failed after n_selected = 41
# Alg NN_lcmd-p_grad_rp-512_acs-rf-hyper-512 failed on step 2 of split 5 of task poker_256x16: filling up with random samples because selection failed after n_selected = 43
# Total number of DBAL steps across all experiments: 564300
# Generating tables...
# Creating learning curve plots...
# Creating individual learning curve plots with subplots...
# Creating skewness plots...
# plot_skewness_ax: R^2 = 0.745615
# Creating correlation plots...
# Creating individual learning curve plots...
# Creating batch size plots...
# Creating individual batch size plots with subplots...
# Creating individual batch size plots...
# Finished plotting
#
# ----- Running evaluation for silu experiments -----
# Loading experiment results...
# Loaded experiment results
# Averaged results across tasks:
# Results for metric mae:
# NN_lcmd-tp_grad_ens-3_rp-512:               -2.035 +- 0.001
# NN_lcmd-tp_grad_rp-512:                     -2.034 +- 0.002
# NN_lcmd-tp_grad:                            -2.031 +- 0.002
# NN_kmeanspp-tp_grad_ens-3_rp-512:           -2.021 +- 0.002
# NN_lcmd-tp_ll_ens-3_rp-512:                 -2.020 +- 0.001
# NN_kmeanspp-tp_grad_rp-512:                 -2.019 +- 0.002
# NN_lcmd-tp_ll:                              -2.019 +- 0.001
# NN_kmeanspp-tp_grad:                        -2.017 +- 0.001
# NN_kmeanspp-tp_ll_ens-3_rp-512:             -2.005 +- 0.001
# NN_kmeanspp-tp_ll:                          -2.003 +- 0.002
# NN_kmeanspp-p_grad_rp-512_acs-grad:         -2.002 +- 0.002
# NN_kmeanspp-p_grad_rp-512_train:            -2.001 +- 0.002
# NN_kmeanspp-p_grad_rp-512_acs-rf-512:       -2.000 +- 0.002
# NN_kmeanspp-p_grad_rp-512_acs-rf-hyper-512: -1.983 +- 0.002
# NN_kmeanspp-p_ll_acs-rf-512:                -1.981 +- 0.001
# NN_lcmd-p_grad_rp-512_acs-rf-512:           -1.977 +- 0.002
# NN_fw-p_grad_rp-512_acs-rf-512:             -1.977 +- 0.001
# NN_kmeanspp-p_ll_train:                     -1.975 +- 0.002
# NN_lcmd-tp_linear:                          -1.968 +- 0.001
# NN_kmeanspp-tp_linear:                      -1.965 +- 0.002
# NN_lcmd-tp_nngp:                            -1.965 +- 0.002
# NN_kmeanspp-tp_nngp:                        -1.963 +- 0.001
# NN_fw-p_grad_rp-512_acs-grad_rp-512:        -1.959 +- 0.002
# NN_fw-p_grad_rp-512_acs-rf-hyper-512:       -1.957 +- 0.002
# NN_fw-p_ll_acs-rf-512:                      -1.957 +- 0.002
# NN_maxdist-tp_ll_ens-3_rp-512:              -1.953 +- 0.002
# NN_lcmd-p_ll_acs-rf-512:                    -1.949 +- 0.002
# NN_maxdet-tp_grad_scale:                    -1.945 +- 0.002
# NN_maxdist-tp_ll:                           -1.944 +- 0.002
# NN_lcmd-p_ll_train:                         -1.930 +- 0.001
# NN_lcmd-p_grad_rp-512_train:                -1.924 +- 0.001
# NN_random:                                  -1.922 +- 0.002
# NN_fw-p_ll_acs-rf-hyper-512:                -1.920 +- 0.002
# NN_maxdist-p_grad_rp-512_train:             -1.912 +- 0.002
# NN_maxdist-tp_grad_ens-3_rp-512:            -1.911 +- 0.002
# NN_maxdist-tp_grad:                         -1.910 +- 0.002
# NN_maxdet-p_grad_rp-512_train:              -1.909 +- 0.001
# NN_maxdist-tp_grad_rp-512:                  -1.909 +- 0.002
# NN_maxdet-p_ll_ens-3_rp-512_train:          -1.908 +- 0.001
# NN_fw-p_ll_acs-grad_rp-512:                 -1.906 +- 0.002
# NN_maxdet-p_grad_ens-3_rp-512_train:        -1.905 +- 0.002
# NN_maxdet-p_grad_rp-512_acs-rf-512:         -1.904 +- 0.001
# NN_lcmd-p_grad_rp-512_acs-grad:             -1.903 +- 0.001
# NN_maxdist-p_ll_train:                      -1.902 +- 0.001
# NN_maxdist-tp_linear:                       -1.901 +- 0.001
# NN_lcmd-p_grad_rp-512_acs-rf-hyper-512:     -1.899 +- 0.001
# NN_maxdist-p_grad_rp-512_acs-rf-512:        -1.898 +- 0.002
# NN_maxdet-p_ll_acs-rf-512:                  -1.897 +- 0.002
# NN_maxdet-p_ll_train:                       -1.893 +- 0.002
# NN_maxdist-p_ll_acs-rf-512:                 -1.893 +- 0.002
# NN_maxdist-tp_nngp:                         -1.889 +- 0.002
# NN_maxdist-p_grad_rp-512_acs-grad:          -1.887 +- 0.002
# NN_maxdet-p_grad_rp-512_acs-grad:           -1.880 +- 0.002
# NN_fw-p_grad_rp-512_train:                  -1.876 +- 0.002
# NN_maxdet-tp_nngp_scale:                    -1.867 +- 0.001
# NN_fw-p_ll_train:                           -1.851 +- 0.002
# NN_maxdist-p_grad_rp-512_acs-rf-hyper-512:  -1.837 +- 0.002
# NN_maxdet-p_grad_rp-512_acs-rf-hyper-512:   -1.834 +- 0.002
# NN_maxdiag_nngp_train:                      -1.770 +- 0.002
# NN_maxdiag_grad_ens-3_rp-512_train:         -1.755 +- 0.002
# NN_maxdiag_grad_train:                      -1.753 +- 0.002
# NN_maxdiag_grad_rp-512_train:               -1.750 +- 0.002
# NN_maxdiag_grad_rp-512_acs-rf-512:          -1.750 +- 0.002
# NN_maxdiag_ll_train:                        -1.736 +- 0.003
# NN_maxdiag_grad_rp-512_acs-grad:            -1.729 +- 0.002
# NN_maxdiag_ll_acs-rf-512:                   -1.725 +- 0.003
# NN_maxdet-p_linear_train:                   -1.715 +- 0.002
# NN_maxdiag_grad_rp-512_acs-rf-hyper-512:    -1.674 +- 0.002
# NN_maxdiag_linear_train:                    -1.632 +- 0.003
#
# Results for metric rmse:
# NN_lcmd-tp_grad_ens-3_rp-512:               -1.595 +- 0.002
# NN_lcmd-tp_grad_rp-512:                     -1.594 +- 0.002
# NN_lcmd-tp_grad:                            -1.591 +- 0.002
# NN_kmeanspp-tp_grad_ens-3_rp-512:           -1.564 +- 0.002
# NN_kmeanspp-tp_grad_rp-512:                 -1.563 +- 0.002
# NN_kmeanspp-tp_grad:                        -1.562 +- 0.002
# NN_kmeanspp-p_grad_rp-512_acs-rf-512:       -1.557 +- 0.002
# NN_lcmd-tp_ll_ens-3_rp-512:                 -1.549 +- 0.002
# NN_lcmd-tp_ll:                              -1.548 +- 0.002
# NN_maxdet-tp_grad_scale:                    -1.539 +- 0.002
# NN_kmeanspp-p_grad_rp-512_acs-grad:         -1.538 +- 0.002
# NN_kmeanspp-p_grad_rp-512_acs-rf-hyper-512: -1.537 +- 0.002
# NN_maxdist-tp_grad_ens-3_rp-512:            -1.534 +- 0.002
# NN_maxdist-tp_grad:                         -1.530 +- 0.002
# NN_maxdist-tp_grad_rp-512:                  -1.530 +- 0.002
# NN_lcmd-p_grad_rp-512_acs-rf-512:           -1.528 +- 0.002
# NN_lcmd-p_grad_rp-512_train:                -1.527 +- 0.001
# NN_kmeanspp-p_grad_rp-512_train:            -1.526 +- 0.002
# NN_fw-p_grad_rp-512_acs-rf-hyper-512:       -1.525 +- 0.002
# NN_kmeanspp-tp_ll_ens-3_rp-512:             -1.521 +- 0.002
# NN_kmeanspp-tp_ll:                          -1.519 +- 0.002
# NN_maxdet-p_grad_ens-3_rp-512_train:        -1.518 +- 0.002
# NN_maxdist-tp_ll_ens-3_rp-512:              -1.518 +- 0.002
# NN_maxdist-p_grad_rp-512_train:             -1.518 +- 0.002
# NN_lcmd-p_grad_rp-512_acs-grad:             -1.517 +- 0.001
# NN_maxdet-p_grad_rp-512_train:              -1.516 +- 0.002
# NN_maxdet-p_grad_rp-512_acs-rf-512:         -1.510 +- 0.002
# NN_maxdist-tp_ll:                           -1.510 +- 0.002
# NN_maxdist-p_grad_rp-512_acs-grad:          -1.505 +- 0.002
# NN_maxdist-p_grad_rp-512_acs-rf-512:        -1.504 +- 0.002
# NN_lcmd-p_grad_rp-512_acs-rf-hyper-512:     -1.503 +- 0.002
# NN_fw-p_grad_rp-512_acs-rf-512:             -1.501 +- 0.002
# NN_maxdet-p_grad_rp-512_acs-grad:           -1.499 +- 0.001
# NN_kmeanspp-p_ll_acs-rf-512:                -1.498 +- 0.002
# NN_lcmd-tp_linear:                          -1.482 +- 0.002
# NN_lcmd-p_ll_train:                         -1.480 +- 0.002
# NN_lcmd-tp_nngp:                            -1.479 +- 0.002
# NN_kmeanspp-p_ll_train:                     -1.476 +- 0.002
# NN_fw-p_grad_rp-512_acs-grad_rp-512:        -1.476 +- 0.002
# NN_maxdet-p_ll_ens-3_rp-512_train:          -1.472 +- 0.002
# NN_fw-p_ll_acs-rf-512:                      -1.465 +- 0.002
# NN_kmeanspp-tp_linear:                      -1.464 +- 0.002
# NN_kmeanspp-tp_nngp:                        -1.461 +- 0.002
# NN_maxdist-p_ll_train:                      -1.458 +- 0.002
# NN_lcmd-p_ll_acs-rf-512:                    -1.457 +- 0.002
# NN_maxdist-p_grad_rp-512_acs-rf-hyper-512:  -1.456 +- 0.002
# NN_maxdet-p_grad_rp-512_acs-rf-hyper-512:   -1.456 +- 0.002
# NN_maxdet-p_ll_acs-rf-512:                  -1.452 +- 0.002
# NN_maxdet-p_ll_train:                       -1.450 +- 0.002
# NN_maxdist-p_ll_acs-rf-512:                 -1.446 +- 0.002
# NN_fw-p_ll_acs-rf-hyper-512:                -1.435 +- 0.002
# NN_maxdist-tp_linear:                       -1.433 +- 0.002
# NN_maxdist-tp_nngp:                         -1.421 +- 0.002
# NN_random:                                  -1.405 +- 0.002
# NN_fw-p_ll_acs-grad_rp-512:                 -1.403 +- 0.002
# NN_maxdet-tp_nngp_scale:                    -1.399 +- 0.002
# NN_fw-p_grad_rp-512_train:                  -1.375 +- 0.002
# NN_maxdiag_grad_ens-3_rp-512_train:         -1.364 +- 0.002
# NN_maxdiag_grad_rp-512_acs-rf-512:          -1.354 +- 0.002
# NN_maxdiag_grad_rp-512_train:               -1.353 +- 0.002
# NN_fw-p_ll_train:                           -1.346 +- 0.002
# NN_maxdiag_grad_train:                      -1.346 +- 0.002
# NN_maxdiag_grad_rp-512_acs-grad:            -1.340 +- 0.002
# NN_maxdiag_nngp_train:                      -1.301 +- 0.002
# NN_maxdiag_ll_acs-rf-512:                   -1.300 +- 0.003
# NN_maxdiag_ll_train:                        -1.287 +- 0.003
# NN_maxdiag_grad_rp-512_acs-rf-hyper-512:    -1.278 +- 0.002
# NN_maxdet-p_linear_train:                   -1.241 +- 0.002
# NN_maxdiag_linear_train:                    -1.166 +- 0.003
#
# Results for metric q95:
# NN_lcmd-tp_grad_ens-3_rp-512:               -0.954 +- 0.002
# NN_lcmd-tp_grad_rp-512:                     -0.953 +- 0.002
# NN_lcmd-tp_grad:                            -0.950 +- 0.002
# NN_kmeanspp-tp_grad_ens-3_rp-512:           -0.930 +- 0.002
# NN_kmeanspp-tp_grad_rp-512:                 -0.928 +- 0.002
# NN_kmeanspp-tp_grad:                        -0.927 +- 0.002
# NN_kmeanspp-p_grad_rp-512_acs-rf-512:       -0.912 +- 0.002
# NN_lcmd-tp_ll_ens-3_rp-512:                 -0.909 +- 0.002
# NN_lcmd-tp_ll:                              -0.908 +- 0.002
# NN_kmeanspp-p_grad_rp-512_acs-grad:         -0.896 +- 0.002
# NN_kmeanspp-p_grad_rp-512_acs-rf-hyper-512: -0.895 +- 0.002
# NN_kmeanspp-p_grad_rp-512_train:            -0.889 +- 0.002
# NN_kmeanspp-tp_ll_ens-3_rp-512:             -0.886 +- 0.002
# NN_maxdet-tp_grad_scale:                    -0.885 +- 0.002
# NN_kmeanspp-tp_ll:                          -0.884 +- 0.002
# NN_lcmd-p_grad_rp-512_acs-rf-512:           -0.883 +- 0.002
# NN_maxdist-tp_grad_ens-3_rp-512:            -0.881 +- 0.002
# NN_maxdist-tp_grad:                         -0.878 +- 0.002
# NN_maxdist-tp_grad_rp-512:                  -0.877 +- 0.002
# NN_fw-p_grad_rp-512_acs-rf-hyper-512:       -0.877 +- 0.002
# NN_maxdist-tp_ll_ens-3_rp-512:              -0.874 +- 0.002
# NN_lcmd-p_grad_rp-512_train:                -0.873 +- 0.001
# NN_maxdist-tp_ll:                           -0.864 +- 0.002
# NN_fw-p_grad_rp-512_acs-rf-512:             -0.864 +- 0.001
# NN_maxdist-p_grad_rp-512_train:             -0.861 +- 0.002
# NN_kmeanspp-p_ll_acs-rf-512:                -0.860 +- 0.002
# NN_maxdet-p_grad_ens-3_rp-512_train:        -0.859 +- 0.002
# NN_maxdet-p_grad_rp-512_train:              -0.859 +- 0.002
# NN_lcmd-p_grad_rp-512_acs-grad:             -0.859 +- 0.001
# NN_maxdet-p_grad_rp-512_acs-rf-512:         -0.851 +- 0.002
# NN_lcmd-p_grad_rp-512_acs-rf-hyper-512:     -0.850 +- 0.002
# NN_maxdist-p_grad_rp-512_acs-rf-512:        -0.843 +- 0.002
# NN_kmeanspp-p_ll_train:                     -0.842 +- 0.002
# NN_maxdist-p_grad_rp-512_acs-grad:          -0.842 +- 0.002
# NN_maxdet-p_grad_rp-512_acs-grad:           -0.835 +- 0.002
# NN_fw-p_grad_rp-512_acs-grad_rp-512:        -0.835 +- 0.002
# NN_lcmd-tp_linear:                          -0.833 +- 0.002
# NN_lcmd-tp_nngp:                            -0.829 +- 0.002
# NN_kmeanspp-tp_linear:                      -0.827 +- 0.002
# NN_fw-p_ll_acs-rf-512:                      -0.826 +- 0.002
# NN_lcmd-p_ll_train:                         -0.826 +- 0.002
# NN_kmeanspp-tp_nngp:                        -0.824 +- 0.002
# NN_lcmd-p_ll_acs-rf-512:                    -0.818 +- 0.002
# NN_maxdet-p_ll_ens-3_rp-512_train:          -0.810 +- 0.002
# NN_maxdist-p_ll_train:                      -0.800 +- 0.002
# NN_maxdet-p_ll_acs-rf-512:                  -0.795 +- 0.002
# NN_fw-p_ll_acs-rf-hyper-512:                -0.793 +- 0.002
# NN_maxdist-p_grad_rp-512_acs-rf-hyper-512:  -0.792 +- 0.002
# NN_maxdet-p_ll_train:                       -0.790 +- 0.002
# NN_maxdet-p_grad_rp-512_acs-rf-hyper-512:   -0.790 +- 0.002
# NN_maxdist-p_ll_acs-rf-512:                 -0.790 +- 0.002
# NN_maxdist-tp_linear:                       -0.773 +- 0.001
# NN_random:                                  -0.772 +- 0.001
# NN_fw-p_ll_acs-grad_rp-512:                 -0.765 +- 0.002
# NN_maxdist-tp_nngp:                         -0.761 +- 0.002
# NN_maxdet-tp_nngp_scale:                    -0.735 +- 0.002
# NN_fw-p_grad_rp-512_train:                  -0.729 +- 0.002
# NN_fw-p_ll_train:                           -0.704 +- 0.002
# NN_maxdiag_grad_ens-3_rp-512_train:         -0.693 +- 0.002
# NN_maxdiag_grad_rp-512_acs-rf-512:          -0.684 +- 0.003
# NN_maxdiag_grad_rp-512_train:               -0.683 +- 0.003
# NN_maxdiag_grad_train:                      -0.679 +- 0.003
# NN_maxdiag_grad_rp-512_acs-grad:            -0.665 +- 0.003
# NN_maxdiag_nngp_train:                      -0.636 +- 0.002
# NN_maxdiag_ll_acs-rf-512:                   -0.626 +- 0.003
# NN_maxdiag_ll_train:                        -0.622 +- 0.003
# NN_maxdiag_grad_rp-512_acs-rf-hyper-512:    -0.604 +- 0.003
# NN_maxdet-p_linear_train:                   -0.576 +- 0.002
# NN_maxdiag_linear_train:                    -0.493 +- 0.003
#
# Results for metric q99:
# NN_lcmd-tp_grad_ens-3_rp-512:               -0.420 +- 0.002
# NN_lcmd-tp_grad_rp-512:                     -0.418 +- 0.002
# NN_lcmd-tp_grad:                            -0.416 +- 0.002
# NN_maxdist-tp_grad_ens-3_rp-512:            -0.408 +- 0.003
# NN_maxdist-tp_grad:                         -0.402 +- 0.003
# NN_maxdist-tp_grad_rp-512:                  -0.400 +- 0.003
# NN_maxdet-tp_grad_scale:                    -0.391 +- 0.002
# NN_lcmd-p_grad_rp-512_train:                -0.387 +- 0.002
# NN_lcmd-p_grad_rp-512_acs-grad:             -0.385 +- 0.002
# NN_maxdet-p_grad_ens-3_rp-512_train:        -0.384 +- 0.002
# NN_kmeanspp-tp_grad_ens-3_rp-512:           -0.380 +- 0.002
# NN_kmeanspp-p_grad_rp-512_acs-rf-512:       -0.379 +- 0.002
# NN_maxdist-p_grad_rp-512_train:             -0.378 +- 0.002
# NN_kmeanspp-tp_grad_rp-512:                 -0.378 +- 0.002
# NN_maxdet-p_grad_rp-512_train:              -0.377 +- 0.002
# NN_kmeanspp-tp_grad:                        -0.377 +- 0.002
# NN_maxdist-p_grad_rp-512_acs-grad:          -0.371 +- 0.002
# NN_maxdet-p_grad_rp-512_acs-grad:           -0.367 +- 0.002
# NN_maxdet-p_grad_rp-512_acs-rf-512:         -0.366 +- 0.002
# NN_lcmd-p_grad_rp-512_acs-rf-hyper-512:     -0.363 +- 0.002
# NN_fw-p_grad_rp-512_acs-rf-hyper-512:       -0.359 +- 0.002
# NN_kmeanspp-p_grad_rp-512_acs-rf-hyper-512: -0.357 +- 0.002
# NN_maxdist-p_grad_rp-512_acs-rf-512:        -0.356 +- 0.002
# NN_lcmd-tp_ll_ens-3_rp-512:                 -0.354 +- 0.002
# NN_lcmd-tp_ll:                              -0.354 +- 0.002
# NN_maxdist-tp_ll_ens-3_rp-512:              -0.352 +- 0.002
# NN_kmeanspp-p_grad_rp-512_acs-grad:         -0.345 +- 0.002
# NN_lcmd-p_grad_rp-512_acs-rf-512:           -0.344 +- 0.002
# NN_maxdist-tp_ll:                           -0.340 +- 0.002
# NN_kmeanspp-p_grad_rp-512_train:            -0.329 +- 0.002
# NN_maxdet-p_grad_rp-512_acs-rf-hyper-512:   -0.322 +- 0.002
# NN_kmeanspp-tp_ll_ens-3_rp-512:             -0.318 +- 0.002
# NN_maxdist-p_grad_rp-512_acs-rf-hyper-512:  -0.317 +- 0.003
# NN_kmeanspp-tp_ll:                          -0.317 +- 0.002
# NN_fw-p_grad_rp-512_acs-rf-512:             -0.301 +- 0.002
# NN_kmeanspp-p_ll_acs-rf-512:                -0.297 +- 0.002
# NN_lcmd-p_ll_train:                         -0.295 +- 0.002
# NN_maxdet-p_ll_ens-3_rp-512_train:          -0.292 +- 0.002
# NN_fw-p_grad_rp-512_acs-grad_rp-512:        -0.273 +- 0.002
# NN_maxdist-p_ll_train:                      -0.272 +- 0.002
# NN_lcmd-tp_linear:                          -0.270 +- 0.002
# NN_lcmd-tp_nngp:                            -0.267 +- 0.002
# NN_maxdet-p_ll_acs-rf-512:                  -0.267 +- 0.002
# NN_kmeanspp-p_ll_train:                     -0.265 +- 0.002
# NN_maxdet-p_ll_train:                       -0.264 +- 0.002
# NN_maxdist-p_ll_acs-rf-512:                 -0.258 +- 0.002
# NN_fw-p_ll_acs-rf-512:                      -0.253 +- 0.002
# NN_kmeanspp-tp_linear:                      -0.247 +- 0.002
# NN_lcmd-p_ll_acs-rf-512:                    -0.245 +- 0.002
# NN_kmeanspp-tp_nngp:                        -0.242 +- 0.002
# NN_maxdist-tp_linear:                       -0.228 +- 0.002
# NN_fw-p_ll_acs-rf-hyper-512:                -0.224 +- 0.002
# NN_maxdist-tp_nngp:                         -0.216 +- 0.002
# NN_maxdiag_grad_ens-3_rp-512_train:         -0.209 +- 0.003
# NN_maxdiag_grad_rp-512_acs-rf-512:          -0.195 +- 0.003
# NN_maxdet-tp_nngp_scale:                    -0.194 +- 0.002
# NN_maxdiag_grad_rp-512_train:               -0.192 +- 0.003
# NN_fw-p_ll_acs-grad_rp-512:                 -0.181 +- 0.002
# NN_maxdiag_grad_train:                      -0.180 +- 0.003
# NN_maxdiag_grad_rp-512_acs-grad:            -0.180 +- 0.003
# NN_random:                                  -0.177 +- 0.002
# NN_fw-p_grad_rp-512_train:                  -0.149 +- 0.002
# NN_fw-p_ll_train:                           -0.116 +- 0.002
# NN_maxdiag_grad_rp-512_acs-rf-hyper-512:    -0.109 +- 0.004
# NN_maxdiag_ll_acs-rf-512:                   -0.103 +- 0.004
# NN_maxdiag_nngp_train:                      -0.095 +- 0.002
# NN_maxdiag_ll_train:                        -0.087 +- 0.003
# NN_maxdet-p_linear_train:                   -0.022 +- 0.003
# NN_maxdiag_linear_train:                    0.061  +- 0.003
#
# Results for metric maxe:
# NN_maxdist-tp_grad:                         0.825 +- 0.008
# NN_maxdist-tp_grad_ens-3_rp-512:            0.825 +- 0.008
# NN_maxdist-tp_grad_rp-512:                  0.827 +- 0.008
# NN_maxdet-tp_grad_scale:                    0.836 +- 0.009
# NN_maxdet-p_grad_ens-3_rp-512_train:        0.843 +- 0.009
# NN_maxdist-p_grad_rp-512_acs-grad:          0.846 +- 0.009
# NN_maxdist-p_grad_rp-512_train:             0.846 +- 0.008
# NN_maxdet-p_grad_rp-512_train:              0.847 +- 0.009
# NN_maxdet-p_grad_rp-512_acs-grad:           0.848 +- 0.008
# NN_lcmd-p_grad_rp-512_acs-grad:             0.850 +- 0.009
# NN_lcmd-p_grad_rp-512_train:                0.853 +- 0.008
# NN_maxdet-p_grad_rp-512_acs-rf-512:         0.855 +- 0.008
# NN_maxdist-p_grad_rp-512_acs-rf-512:        0.865 +- 0.008
# NN_maxdist-p_grad_rp-512_acs-rf-hyper-512:  0.866 +- 0.008
# NN_maxdet-p_grad_rp-512_acs-rf-hyper-512:   0.867 +- 0.008
# NN_lcmd-p_grad_rp-512_acs-rf-hyper-512:     0.872 +- 0.008
# NN_maxdist-tp_ll:                           0.885 +- 0.008
# NN_maxdist-tp_ll_ens-3_rp-512:              0.889 +- 0.008
# NN_maxdet-p_ll_ens-3_rp-512_train:          0.901 +- 0.007
# NN_lcmd-tp_grad_rp-512:                     0.909 +- 0.008
# NN_lcmd-tp_grad:                            0.910 +- 0.008
# NN_lcmd-tp_grad_ens-3_rp-512:               0.910 +- 0.008
# NN_kmeanspp-p_grad_rp-512_acs-rf-512:       0.919 +- 0.008
# NN_maxdet-p_ll_train:                       0.921 +- 0.007
# NN_fw-p_grad_rp-512_acs-rf-hyper-512:       0.924 +- 0.008
# NN_maxdist-p_ll_train:                      0.924 +- 0.007
# NN_lcmd-p_ll_train:                         0.926 +- 0.007
# NN_maxdet-p_ll_acs-rf-512:                  0.927 +- 0.006
# NN_maxdist-p_ll_acs-rf-512:                 0.938 +- 0.007
# NN_lcmd-tp_ll:                              0.940 +- 0.007
# NN_lcmd-tp_ll_ens-3_rp-512:                 0.943 +- 0.007
# NN_maxdiag_grad_ens-3_rp-512_train:         0.949 +- 0.007
# NN_lcmd-p_grad_rp-512_acs-rf-512:           0.960 +- 0.008
# NN_maxdiag_grad_rp-512_acs-grad:            0.962 +- 0.007
# NN_maxdiag_grad_rp-512_train:               0.965 +- 0.007
# NN_maxdiag_grad_rp-512_acs-rf-512:          0.966 +- 0.007
# NN_kmeanspp-tp_grad:                        0.966 +- 0.007
# NN_kmeanspp-tp_grad_rp-512:                 0.968 +- 0.008
# NN_kmeanspp-p_grad_rp-512_acs-rf-hyper-512: 0.972 +- 0.009
# NN_kmeanspp-tp_grad_ens-3_rp-512:           0.974 +- 0.008
# NN_maxdiag_grad_train:                      0.974 +- 0.007
# NN_kmeanspp-p_grad_rp-512_acs-grad:         0.977 +- 0.008
# NN_maxdet-tp_nngp_scale:                    0.978 +- 0.006
# NN_kmeanspp-p_ll_acs-rf-512:                0.983 +- 0.007
# NN_maxdist-tp_linear:                       0.985 +- 0.006
# NN_maxdist-tp_nngp:                         0.988 +- 0.006
# NN_lcmd-tp_linear:                          0.994 +- 0.006
# NN_kmeanspp-p_grad_rp-512_train:            0.999 +- 0.008
# NN_lcmd-tp_nngp:                            1.002 +- 0.007
# NN_kmeanspp-tp_ll:                          1.002 +- 0.008
# NN_kmeanspp-tp_ll_ens-3_rp-512:             1.003 +- 0.007
# NN_maxdiag_grad_rp-512_acs-rf-hyper-512:    1.010 +- 0.007
# NN_fw-p_ll_acs-rf-hyper-512:                1.022 +- 0.007
# NN_lcmd-p_ll_acs-rf-512:                    1.023 +- 0.007
# NN_fw-p_grad_rp-512_acs-rf-512:             1.025 +- 0.008
# NN_maxdiag_ll_acs-rf-512:                   1.035 +- 0.007
# NN_fw-p_ll_acs-rf-512:                      1.036 +- 0.007
# NN_kmeanspp-p_ll_train:                     1.041 +- 0.008
# NN_maxdiag_ll_train:                        1.041 +- 0.006
# NN_maxdiag_nngp_train:                      1.049 +- 0.005
# NN_kmeanspp-tp_linear:                      1.054 +- 0.008
# NN_fw-p_grad_rp-512_acs-grad_rp-512:        1.057 +- 0.008
# NN_kmeanspp-tp_nngp:                        1.064 +- 0.007
# NN_fw-p_ll_acs-grad_rp-512:                 1.107 +- 0.008
# NN_random:                                  1.116 +- 0.007
# NN_maxdet-p_linear_train:                   1.116 +- 0.005
# NN_fw-p_grad_rp-512_train:                  1.148 +- 0.008
# NN_maxdiag_linear_train:                    1.151 +- 0.005
# NN_fw-p_ll_train:                           1.155 +- 0.007
#
#
#
#
# Analyzing results
# eff dim was larger for grad_rp-512 than for ll in 89.8958% of cases
# avg eff dim for grad_rp-512: 3.99224
# avg eff dim for ll: 2.31807
# Alg NN_kmeanspp-p_grad_rp-512_acs-rf-hyper-512 failed on step 9 of split 0 of task mlr_knn_rng_256x16: filling up with random samples because selection failed after n_selected = 219
# Alg NN_kmeanspp-p_grad_rp-512_acs-rf-hyper-512 failed on step 7 of split 0 of task fried_256x16: filling up with random samples because selection failed after n_selected = 194
# Total number of DBAL steps across all experiments: 331200
# Generating tables...
# Creating learning curve plots...
# Creating individual learning curve plots with subplots...
# Creating skewness plots...
# plot_skewness_ax: R^2 = 0.790182
# Creating correlation plots...
# Creating individual learning curve plots...
# Finished plotting
#
# Creating lcmd visualization...

# %% [markdown]
# Note that running `run_evaluation.py` for a second time will load the data faster unless the results folder has been modified. This is because it caches the results in a more efficient format in the cache folder configured in `custom_paths.py`. We can see that the results are grouped into `relu` and `silu` experiments, which matches the two subfolders in the results folder. We can choose to run the evaluation only on the `silu` subfolder:

# %%
# !python3 run_evaluation.py silu
# Out:
# ----- Running evaluation for silu experiments -----
# Loading experiment results...
# Loaded experiment results
# Averaged results across tasks:
# Results for metric mae:
# NN_lcmd-tp_grad_ens-3_rp-512:               -2.035 +- 0.001
# NN_lcmd-tp_grad_rp-512:                     -2.034 +- 0.002
# NN_lcmd-tp_grad:                            -2.031 +- 0.002
# NN_kmeanspp-tp_grad_ens-3_rp-512:           -2.021 +- 0.002
# NN_lcmd-tp_ll_ens-3_rp-512:                 -2.020 +- 0.001
# NN_kmeanspp-tp_grad_rp-512:                 -2.019 +- 0.002
# NN_lcmd-tp_ll:                              -2.019 +- 0.001
# NN_kmeanspp-tp_grad:                        -2.017 +- 0.001
# NN_kmeanspp-tp_ll_ens-3_rp-512:             -2.005 +- 0.001
# NN_kmeanspp-tp_ll:                          -2.003 +- 0.002
# NN_kmeanspp-p_grad_rp-512_acs-grad:         -2.002 +- 0.002
# NN_kmeanspp-p_grad_rp-512_train:            -2.001 +- 0.002
# NN_kmeanspp-p_grad_rp-512_acs-rf-512:       -2.000 +- 0.002
# NN_kmeanspp-p_grad_rp-512_acs-rf-hyper-512: -1.983 +- 0.002
# NN_kmeanspp-p_ll_acs-rf-512:                -1.981 +- 0.001
# NN_lcmd-p_grad_rp-512_acs-rf-512:           -1.977 +- 0.002
# NN_fw-p_grad_rp-512_acs-rf-512:             -1.977 +- 0.001
# NN_kmeanspp-p_ll_train:                     -1.975 +- 0.002
# NN_lcmd-tp_linear:                          -1.968 +- 0.001
# NN_kmeanspp-tp_linear:                      -1.965 +- 0.002
# NN_lcmd-tp_nngp:                            -1.965 +- 0.002
# NN_kmeanspp-tp_nngp:                        -1.963 +- 0.001
# NN_fw-p_grad_rp-512_acs-grad_rp-512:        -1.959 +- 0.002
# NN_fw-p_grad_rp-512_acs-rf-hyper-512:       -1.957 +- 0.002
# NN_fw-p_ll_acs-rf-512:                      -1.957 +- 0.002
# NN_maxdist-tp_ll_ens-3_rp-512:              -1.953 +- 0.002
# NN_lcmd-p_ll_acs-rf-512:                    -1.949 +- 0.002
# NN_maxdet-tp_grad_scale:                    -1.945 +- 0.002
# NN_maxdist-tp_ll:                           -1.944 +- 0.002
# NN_lcmd-p_ll_train:                         -1.930 +- 0.001
# NN_lcmd-p_grad_rp-512_train:                -1.924 +- 0.001
# NN_random:                                  -1.922 +- 0.002
# NN_fw-p_ll_acs-rf-hyper-512:                -1.920 +- 0.002
# NN_maxdist-p_grad_rp-512_train:             -1.912 +- 0.002
# NN_maxdist-tp_grad_ens-3_rp-512:            -1.911 +- 0.002
# NN_maxdist-tp_grad:                         -1.910 +- 0.002
# NN_maxdet-p_grad_rp-512_train:              -1.909 +- 0.001
# NN_maxdist-tp_grad_rp-512:                  -1.909 +- 0.002
# NN_maxdet-p_ll_ens-3_rp-512_train:          -1.908 +- 0.001
# NN_fw-p_ll_acs-grad_rp-512:                 -1.906 +- 0.002
# NN_maxdet-p_grad_ens-3_rp-512_train:        -1.905 +- 0.002
# NN_maxdet-p_grad_rp-512_acs-rf-512:         -1.904 +- 0.001
# NN_lcmd-p_grad_rp-512_acs-grad:             -1.903 +- 0.001
# NN_maxdist-p_ll_train:                      -1.902 +- 0.001
# NN_maxdist-tp_linear:                       -1.901 +- 0.001
# NN_lcmd-p_grad_rp-512_acs-rf-hyper-512:     -1.899 +- 0.001
# NN_maxdist-p_grad_rp-512_acs-rf-512:        -1.898 +- 0.002
# NN_maxdet-p_ll_acs-rf-512:                  -1.897 +- 0.002
# NN_maxdet-p_ll_train:                       -1.893 +- 0.002
# NN_maxdist-p_ll_acs-rf-512:                 -1.893 +- 0.002
# NN_maxdist-tp_nngp:                         -1.889 +- 0.002
# NN_maxdist-p_grad_rp-512_acs-grad:          -1.887 +- 0.002
# NN_maxdet-p_grad_rp-512_acs-grad:           -1.880 +- 0.002
# NN_fw-p_grad_rp-512_train:                  -1.876 +- 0.002
# NN_maxdet-tp_nngp_scale:                    -1.867 +- 0.001
# NN_fw-p_ll_train:                           -1.851 +- 0.002
# NN_maxdist-p_grad_rp-512_acs-rf-hyper-512:  -1.837 +- 0.002
# NN_maxdet-p_grad_rp-512_acs-rf-hyper-512:   -1.834 +- 0.002
# NN_maxdiag_nngp_train:                      -1.770 +- 0.002
# NN_maxdiag_grad_ens-3_rp-512_train:         -1.755 +- 0.002
# NN_maxdiag_grad_train:                      -1.753 +- 0.002
# NN_maxdiag_grad_rp-512_train:               -1.750 +- 0.002
# NN_maxdiag_grad_rp-512_acs-rf-512:          -1.750 +- 0.002
# NN_maxdiag_ll_train:                        -1.736 +- 0.003
# NN_maxdiag_grad_rp-512_acs-grad:            -1.729 +- 0.002
# NN_maxdiag_ll_acs-rf-512:                   -1.725 +- 0.003
# NN_maxdet-p_linear_train:                   -1.715 +- 0.002
# NN_maxdiag_grad_rp-512_acs-rf-hyper-512:    -1.674 +- 0.002
# NN_maxdiag_linear_train:                    -1.632 +- 0.003
#
# Results for metric rmse:
# NN_lcmd-tp_grad_ens-3_rp-512:               -1.595 +- 0.002
# NN_lcmd-tp_grad_rp-512:                     -1.594 +- 0.002
# NN_lcmd-tp_grad:                            -1.591 +- 0.002
# NN_kmeanspp-tp_grad_ens-3_rp-512:           -1.564 +- 0.002
# NN_kmeanspp-tp_grad_rp-512:                 -1.563 +- 0.002
# NN_kmeanspp-tp_grad:                        -1.562 +- 0.002
# NN_kmeanspp-p_grad_rp-512_acs-rf-512:       -1.557 +- 0.002
# NN_lcmd-tp_ll_ens-3_rp-512:                 -1.549 +- 0.002
# NN_lcmd-tp_ll:                              -1.548 +- 0.002
# NN_maxdet-tp_grad_scale:                    -1.539 +- 0.002
# NN_kmeanspp-p_grad_rp-512_acs-grad:         -1.538 +- 0.002
# NN_kmeanspp-p_grad_rp-512_acs-rf-hyper-512: -1.537 +- 0.002
# NN_maxdist-tp_grad_ens-3_rp-512:            -1.534 +- 0.002
# NN_maxdist-tp_grad:                         -1.530 +- 0.002
# NN_maxdist-tp_grad_rp-512:                  -1.530 +- 0.002
# NN_lcmd-p_grad_rp-512_acs-rf-512:           -1.528 +- 0.002
# NN_lcmd-p_grad_rp-512_train:                -1.527 +- 0.001
# NN_kmeanspp-p_grad_rp-512_train:            -1.526 +- 0.002
# NN_fw-p_grad_rp-512_acs-rf-hyper-512:       -1.525 +- 0.002
# NN_kmeanspp-tp_ll_ens-3_rp-512:             -1.521 +- 0.002
# NN_kmeanspp-tp_ll:                          -1.519 +- 0.002
# NN_maxdet-p_grad_ens-3_rp-512_train:        -1.518 +- 0.002
# NN_maxdist-tp_ll_ens-3_rp-512:              -1.518 +- 0.002
# NN_maxdist-p_grad_rp-512_train:             -1.518 +- 0.002
# NN_lcmd-p_grad_rp-512_acs-grad:             -1.517 +- 0.001
# NN_maxdet-p_grad_rp-512_train:              -1.516 +- 0.002
# NN_maxdet-p_grad_rp-512_acs-rf-512:         -1.510 +- 0.002
# NN_maxdist-tp_ll:                           -1.510 +- 0.002
# NN_maxdist-p_grad_rp-512_acs-grad:          -1.505 +- 0.002
# NN_maxdist-p_grad_rp-512_acs-rf-512:        -1.504 +- 0.002
# NN_lcmd-p_grad_rp-512_acs-rf-hyper-512:     -1.503 +- 0.002
# NN_fw-p_grad_rp-512_acs-rf-512:             -1.501 +- 0.002
# NN_maxdet-p_grad_rp-512_acs-grad:           -1.499 +- 0.001
# NN_kmeanspp-p_ll_acs-rf-512:                -1.498 +- 0.002
# NN_lcmd-tp_linear:                          -1.482 +- 0.002
# NN_lcmd-p_ll_train:                         -1.480 +- 0.002
# NN_lcmd-tp_nngp:                            -1.479 +- 0.002
# NN_kmeanspp-p_ll_train:                     -1.476 +- 0.002
# NN_fw-p_grad_rp-512_acs-grad_rp-512:        -1.476 +- 0.002
# NN_maxdet-p_ll_ens-3_rp-512_train:          -1.472 +- 0.002
# NN_fw-p_ll_acs-rf-512:                      -1.465 +- 0.002
# NN_kmeanspp-tp_linear:                      -1.464 +- 0.002
# NN_kmeanspp-tp_nngp:                        -1.461 +- 0.002
# NN_maxdist-p_ll_train:                      -1.458 +- 0.002
# NN_lcmd-p_ll_acs-rf-512:                    -1.457 +- 0.002
# NN_maxdist-p_grad_rp-512_acs-rf-hyper-512:  -1.456 +- 0.002
# NN_maxdet-p_grad_rp-512_acs-rf-hyper-512:   -1.456 +- 0.002
# NN_maxdet-p_ll_acs-rf-512:                  -1.452 +- 0.002
# NN_maxdet-p_ll_train:                       -1.450 +- 0.002
# NN_maxdist-p_ll_acs-rf-512:                 -1.446 +- 0.002
# NN_fw-p_ll_acs-rf-hyper-512:                -1.435 +- 0.002
# NN_maxdist-tp_linear:                       -1.433 +- 0.002
# NN_maxdist-tp_nngp:                         -1.421 +- 0.002
# NN_random:                                  -1.405 +- 0.002
# NN_fw-p_ll_acs-grad_rp-512:                 -1.403 +- 0.002
# NN_maxdet-tp_nngp_scale:                    -1.399 +- 0.002
# NN_fw-p_grad_rp-512_train:                  -1.375 +- 0.002
# NN_maxdiag_grad_ens-3_rp-512_train:         -1.364 +- 0.002
# NN_maxdiag_grad_rp-512_acs-rf-512:          -1.354 +- 0.002
# NN_maxdiag_grad_rp-512_train:               -1.353 +- 0.002
# NN_fw-p_ll_train:                           -1.346 +- 0.002
# NN_maxdiag_grad_train:                      -1.346 +- 0.002
# NN_maxdiag_grad_rp-512_acs-grad:            -1.340 +- 0.002
# NN_maxdiag_nngp_train:                      -1.301 +- 0.002
# NN_maxdiag_ll_acs-rf-512:                   -1.300 +- 0.003
# NN_maxdiag_ll_train:                        -1.287 +- 0.003
# NN_maxdiag_grad_rp-512_acs-rf-hyper-512:    -1.278 +- 0.002
# NN_maxdet-p_linear_train:                   -1.241 +- 0.002
# NN_maxdiag_linear_train:                    -1.166 +- 0.003
#
# Results for metric q95:
# NN_lcmd-tp_grad_ens-3_rp-512:               -0.954 +- 0.002
# NN_lcmd-tp_grad_rp-512:                     -0.953 +- 0.002
# NN_lcmd-tp_grad:                            -0.950 +- 0.002
# NN_kmeanspp-tp_grad_ens-3_rp-512:           -0.930 +- 0.002
# NN_kmeanspp-tp_grad_rp-512:                 -0.928 +- 0.002
# NN_kmeanspp-tp_grad:                        -0.927 +- 0.002
# NN_kmeanspp-p_grad_rp-512_acs-rf-512:       -0.912 +- 0.002
# NN_lcmd-tp_ll_ens-3_rp-512:                 -0.909 +- 0.002
# NN_lcmd-tp_ll:                              -0.908 +- 0.002
# NN_kmeanspp-p_grad_rp-512_acs-grad:         -0.896 +- 0.002
# NN_kmeanspp-p_grad_rp-512_acs-rf-hyper-512: -0.895 +- 0.002
# NN_kmeanspp-p_grad_rp-512_train:            -0.889 +- 0.002
# NN_kmeanspp-tp_ll_ens-3_rp-512:             -0.886 +- 0.002
# NN_maxdet-tp_grad_scale:                    -0.885 +- 0.002
# NN_kmeanspp-tp_ll:                          -0.884 +- 0.002
# NN_lcmd-p_grad_rp-512_acs-rf-512:           -0.883 +- 0.002
# NN_maxdist-tp_grad_ens-3_rp-512:            -0.881 +- 0.002
# NN_maxdist-tp_grad:                         -0.878 +- 0.002
# NN_maxdist-tp_grad_rp-512:                  -0.877 +- 0.002
# NN_fw-p_grad_rp-512_acs-rf-hyper-512:       -0.877 +- 0.002
# NN_maxdist-tp_ll_ens-3_rp-512:              -0.874 +- 0.002
# NN_lcmd-p_grad_rp-512_train:                -0.873 +- 0.001
# NN_maxdist-tp_ll:                           -0.864 +- 0.002
# NN_fw-p_grad_rp-512_acs-rf-512:             -0.864 +- 0.001
# NN_maxdist-p_grad_rp-512_train:             -0.861 +- 0.002
# NN_kmeanspp-p_ll_acs-rf-512:                -0.860 +- 0.002
# NN_maxdet-p_grad_ens-3_rp-512_train:        -0.859 +- 0.002
# NN_maxdet-p_grad_rp-512_train:              -0.859 +- 0.002
# NN_lcmd-p_grad_rp-512_acs-grad:             -0.859 +- 0.001
# NN_maxdet-p_grad_rp-512_acs-rf-512:         -0.851 +- 0.002
# NN_lcmd-p_grad_rp-512_acs-rf-hyper-512:     -0.850 +- 0.002
# NN_maxdist-p_grad_rp-512_acs-rf-512:        -0.843 +- 0.002
# NN_kmeanspp-p_ll_train:                     -0.842 +- 0.002
# NN_maxdist-p_grad_rp-512_acs-grad:          -0.842 +- 0.002
# NN_maxdet-p_grad_rp-512_acs-grad:           -0.835 +- 0.002
# NN_fw-p_grad_rp-512_acs-grad_rp-512:        -0.835 +- 0.002
# NN_lcmd-tp_linear:                          -0.833 +- 0.002
# NN_lcmd-tp_nngp:                            -0.829 +- 0.002
# NN_kmeanspp-tp_linear:                      -0.827 +- 0.002
# NN_fw-p_ll_acs-rf-512:                      -0.826 +- 0.002
# NN_lcmd-p_ll_train:                         -0.826 +- 0.002
# NN_kmeanspp-tp_nngp:                        -0.824 +- 0.002
# NN_lcmd-p_ll_acs-rf-512:                    -0.818 +- 0.002
# NN_maxdet-p_ll_ens-3_rp-512_train:          -0.810 +- 0.002
# NN_maxdist-p_ll_train:                      -0.800 +- 0.002
# NN_maxdet-p_ll_acs-rf-512:                  -0.795 +- 0.002
# NN_fw-p_ll_acs-rf-hyper-512:                -0.793 +- 0.002
# NN_maxdist-p_grad_rp-512_acs-rf-hyper-512:  -0.792 +- 0.002
# NN_maxdet-p_ll_train:                       -0.790 +- 0.002
# NN_maxdet-p_grad_rp-512_acs-rf-hyper-512:   -0.790 +- 0.002
# NN_maxdist-p_ll_acs-rf-512:                 -0.790 +- 0.002
# NN_maxdist-tp_linear:                       -0.773 +- 0.001
# NN_random:                                  -0.772 +- 0.001
# NN_fw-p_ll_acs-grad_rp-512:                 -0.765 +- 0.002
# NN_maxdist-tp_nngp:                         -0.761 +- 0.002
# NN_maxdet-tp_nngp_scale:                    -0.735 +- 0.002
# NN_fw-p_grad_rp-512_train:                  -0.729 +- 0.002
# NN_fw-p_ll_train:                           -0.704 +- 0.002
# NN_maxdiag_grad_ens-3_rp-512_train:         -0.693 +- 0.002
# NN_maxdiag_grad_rp-512_acs-rf-512:          -0.684 +- 0.003
# NN_maxdiag_grad_rp-512_train:               -0.683 +- 0.003
# NN_maxdiag_grad_train:                      -0.679 +- 0.003
# NN_maxdiag_grad_rp-512_acs-grad:            -0.665 +- 0.003
# NN_maxdiag_nngp_train:                      -0.636 +- 0.002
# NN_maxdiag_ll_acs-rf-512:                   -0.626 +- 0.003
# NN_maxdiag_ll_train:                        -0.622 +- 0.003
# NN_maxdiag_grad_rp-512_acs-rf-hyper-512:    -0.604 +- 0.003
# NN_maxdet-p_linear_train:                   -0.576 +- 0.002
# NN_maxdiag_linear_train:                    -0.493 +- 0.003
#
# Results for metric q99:
# NN_lcmd-tp_grad_ens-3_rp-512:               -0.420 +- 0.002
# NN_lcmd-tp_grad_rp-512:                     -0.418 +- 0.002
# NN_lcmd-tp_grad:                            -0.416 +- 0.002
# NN_maxdist-tp_grad_ens-3_rp-512:            -0.408 +- 0.003
# NN_maxdist-tp_grad:                         -0.402 +- 0.003
# NN_maxdist-tp_grad_rp-512:                  -0.400 +- 0.003
# NN_maxdet-tp_grad_scale:                    -0.391 +- 0.002
# NN_lcmd-p_grad_rp-512_train:                -0.387 +- 0.002
# NN_lcmd-p_grad_rp-512_acs-grad:             -0.385 +- 0.002
# NN_maxdet-p_grad_ens-3_rp-512_train:        -0.384 +- 0.002
# NN_kmeanspp-tp_grad_ens-3_rp-512:           -0.380 +- 0.002
# NN_kmeanspp-p_grad_rp-512_acs-rf-512:       -0.379 +- 0.002
# NN_maxdist-p_grad_rp-512_train:             -0.378 +- 0.002
# NN_kmeanspp-tp_grad_rp-512:                 -0.378 +- 0.002
# NN_maxdet-p_grad_rp-512_train:              -0.377 +- 0.002
# NN_kmeanspp-tp_grad:                        -0.377 +- 0.002
# NN_maxdist-p_grad_rp-512_acs-grad:          -0.371 +- 0.002
# NN_maxdet-p_grad_rp-512_acs-grad:           -0.367 +- 0.002
# NN_maxdet-p_grad_rp-512_acs-rf-512:         -0.366 +- 0.002
# NN_lcmd-p_grad_rp-512_acs-rf-hyper-512:     -0.363 +- 0.002
# NN_fw-p_grad_rp-512_acs-rf-hyper-512:       -0.359 +- 0.002
# NN_kmeanspp-p_grad_rp-512_acs-rf-hyper-512: -0.357 +- 0.002
# NN_maxdist-p_grad_rp-512_acs-rf-512:        -0.356 +- 0.002
# NN_lcmd-tp_ll_ens-3_rp-512:                 -0.354 +- 0.002
# NN_lcmd-tp_ll:                              -0.354 +- 0.002
# NN_maxdist-tp_ll_ens-3_rp-512:              -0.352 +- 0.002
# NN_kmeanspp-p_grad_rp-512_acs-grad:         -0.345 +- 0.002
# NN_lcmd-p_grad_rp-512_acs-rf-512:           -0.344 +- 0.002
# NN_maxdist-tp_ll:                           -0.340 +- 0.002
# NN_kmeanspp-p_grad_rp-512_train:            -0.329 +- 0.002
# NN_maxdet-p_grad_rp-512_acs-rf-hyper-512:   -0.322 +- 0.002
# NN_kmeanspp-tp_ll_ens-3_rp-512:             -0.318 +- 0.002
# NN_maxdist-p_grad_rp-512_acs-rf-hyper-512:  -0.317 +- 0.003
# NN_kmeanspp-tp_ll:                          -0.317 +- 0.002
# NN_fw-p_grad_rp-512_acs-rf-512:             -0.301 +- 0.002
# NN_kmeanspp-p_ll_acs-rf-512:                -0.297 +- 0.002
# NN_lcmd-p_ll_train:                         -0.295 +- 0.002
# NN_maxdet-p_ll_ens-3_rp-512_train:          -0.292 +- 0.002
# NN_fw-p_grad_rp-512_acs-grad_rp-512:        -0.273 +- 0.002
# NN_maxdist-p_ll_train:                      -0.272 +- 0.002
# NN_lcmd-tp_linear:                          -0.270 +- 0.002
# NN_lcmd-tp_nngp:                            -0.267 +- 0.002
# NN_maxdet-p_ll_acs-rf-512:                  -0.267 +- 0.002
# NN_kmeanspp-p_ll_train:                     -0.265 +- 0.002
# NN_maxdet-p_ll_train:                       -0.264 +- 0.002
# NN_maxdist-p_ll_acs-rf-512:                 -0.258 +- 0.002
# NN_fw-p_ll_acs-rf-512:                      -0.253 +- 0.002
# NN_kmeanspp-tp_linear:                      -0.247 +- 0.002
# NN_lcmd-p_ll_acs-rf-512:                    -0.245 +- 0.002
# NN_kmeanspp-tp_nngp:                        -0.242 +- 0.002
# NN_maxdist-tp_linear:                       -0.228 +- 0.002
# NN_fw-p_ll_acs-rf-hyper-512:                -0.224 +- 0.002
# NN_maxdist-tp_nngp:                         -0.216 +- 0.002
# NN_maxdiag_grad_ens-3_rp-512_train:         -0.209 +- 0.003
# NN_maxdiag_grad_rp-512_acs-rf-512:          -0.195 +- 0.003
# NN_maxdet-tp_nngp_scale:                    -0.194 +- 0.002
# NN_maxdiag_grad_rp-512_train:               -0.192 +- 0.003
# NN_fw-p_ll_acs-grad_rp-512:                 -0.181 +- 0.002
# NN_maxdiag_grad_train:                      -0.180 +- 0.003
# NN_maxdiag_grad_rp-512_acs-grad:            -0.180 +- 0.003
# NN_random:                                  -0.177 +- 0.002
# NN_fw-p_grad_rp-512_train:                  -0.149 +- 0.002
# NN_fw-p_ll_train:                           -0.116 +- 0.002
# NN_maxdiag_grad_rp-512_acs-rf-hyper-512:    -0.109 +- 0.004
# NN_maxdiag_ll_acs-rf-512:                   -0.103 +- 0.004
# NN_maxdiag_nngp_train:                      -0.095 +- 0.002
# NN_maxdiag_ll_train:                        -0.087 +- 0.003
# NN_maxdet-p_linear_train:                   -0.022 +- 0.003
# NN_maxdiag_linear_train:                    0.061  +- 0.003
#
# Results for metric maxe:
# NN_maxdist-tp_grad:                         0.825 +- 0.008
# NN_maxdist-tp_grad_ens-3_rp-512:            0.825 +- 0.008
# NN_maxdist-tp_grad_rp-512:                  0.827 +- 0.008
# NN_maxdet-tp_grad_scale:                    0.836 +- 0.009
# NN_maxdet-p_grad_ens-3_rp-512_train:        0.843 +- 0.009
# NN_maxdist-p_grad_rp-512_acs-grad:          0.846 +- 0.009
# NN_maxdist-p_grad_rp-512_train:             0.846 +- 0.008
# NN_maxdet-p_grad_rp-512_train:              0.847 +- 0.009
# NN_maxdet-p_grad_rp-512_acs-grad:           0.848 +- 0.008
# NN_lcmd-p_grad_rp-512_acs-grad:             0.850 +- 0.009
# NN_lcmd-p_grad_rp-512_train:                0.853 +- 0.008
# NN_maxdet-p_grad_rp-512_acs-rf-512:         0.855 +- 0.008
# NN_maxdist-p_grad_rp-512_acs-rf-512:        0.865 +- 0.008
# NN_maxdist-p_grad_rp-512_acs-rf-hyper-512:  0.866 +- 0.008
# NN_maxdet-p_grad_rp-512_acs-rf-hyper-512:   0.867 +- 0.008
# NN_lcmd-p_grad_rp-512_acs-rf-hyper-512:     0.872 +- 0.008
# NN_maxdist-tp_ll:                           0.885 +- 0.008
# NN_maxdist-tp_ll_ens-3_rp-512:              0.889 +- 0.008
# NN_maxdet-p_ll_ens-3_rp-512_train:          0.901 +- 0.007
# NN_lcmd-tp_grad_rp-512:                     0.909 +- 0.008
# NN_lcmd-tp_grad:                            0.910 +- 0.008
# NN_lcmd-tp_grad_ens-3_rp-512:               0.910 +- 0.008
# NN_kmeanspp-p_grad_rp-512_acs-rf-512:       0.919 +- 0.008
# NN_maxdet-p_ll_train:                       0.921 +- 0.007
# NN_fw-p_grad_rp-512_acs-rf-hyper-512:       0.924 +- 0.008
# NN_maxdist-p_ll_train:                      0.924 +- 0.007
# NN_lcmd-p_ll_train:                         0.926 +- 0.007
# NN_maxdet-p_ll_acs-rf-512:                  0.927 +- 0.006
# NN_maxdist-p_ll_acs-rf-512:                 0.938 +- 0.007
# NN_lcmd-tp_ll:                              0.940 +- 0.007
# NN_lcmd-tp_ll_ens-3_rp-512:                 0.943 +- 0.007
# NN_maxdiag_grad_ens-3_rp-512_train:         0.949 +- 0.007
# NN_lcmd-p_grad_rp-512_acs-rf-512:           0.960 +- 0.008
# NN_maxdiag_grad_rp-512_acs-grad:            0.962 +- 0.007
# NN_maxdiag_grad_rp-512_train:               0.965 +- 0.007
# NN_maxdiag_grad_rp-512_acs-rf-512:          0.966 +- 0.007
# NN_kmeanspp-tp_grad:                        0.966 +- 0.007
# NN_kmeanspp-tp_grad_rp-512:                 0.968 +- 0.008
# NN_kmeanspp-p_grad_rp-512_acs-rf-hyper-512: 0.972 +- 0.009
# NN_kmeanspp-tp_grad_ens-3_rp-512:           0.974 +- 0.008
# NN_maxdiag_grad_train:                      0.974 +- 0.007
# NN_kmeanspp-p_grad_rp-512_acs-grad:         0.977 +- 0.008
# NN_maxdet-tp_nngp_scale:                    0.978 +- 0.006
# NN_kmeanspp-p_ll_acs-rf-512:                0.983 +- 0.007
# NN_maxdist-tp_linear:                       0.985 +- 0.006
# NN_maxdist-tp_nngp:                         0.988 +- 0.006
# NN_lcmd-tp_linear:                          0.994 +- 0.006
# NN_kmeanspp-p_grad_rp-512_train:            0.999 +- 0.008
# NN_lcmd-tp_nngp:                            1.002 +- 0.007
# NN_kmeanspp-tp_ll:                          1.002 +- 0.008
# NN_kmeanspp-tp_ll_ens-3_rp-512:             1.003 +- 0.007
# NN_maxdiag_grad_rp-512_acs-rf-hyper-512:    1.010 +- 0.007
# NN_fw-p_ll_acs-rf-hyper-512:                1.022 +- 0.007
# NN_lcmd-p_ll_acs-rf-512:                    1.023 +- 0.007
# NN_fw-p_grad_rp-512_acs-rf-512:             1.025 +- 0.008
# NN_maxdiag_ll_acs-rf-512:                   1.035 +- 0.007
# NN_fw-p_ll_acs-rf-512:                      1.036 +- 0.007
# NN_kmeanspp-p_ll_train:                     1.041 +- 0.008
# NN_maxdiag_ll_train:                        1.041 +- 0.006
# NN_maxdiag_nngp_train:                      1.049 +- 0.005
# NN_kmeanspp-tp_linear:                      1.054 +- 0.008
# NN_fw-p_grad_rp-512_acs-grad_rp-512:        1.057 +- 0.008
# NN_kmeanspp-tp_nngp:                        1.064 +- 0.007
# NN_fw-p_ll_acs-grad_rp-512:                 1.107 +- 0.008
# NN_random:                                  1.116 +- 0.007
# NN_maxdet-p_linear_train:                   1.116 +- 0.005
# NN_fw-p_grad_rp-512_train:                  1.148 +- 0.008
# NN_maxdiag_linear_train:                    1.151 +- 0.005
# NN_fw-p_ll_train:                           1.155 +- 0.007
#
#
#
#
# Analyzing results
# eff dim was larger for grad_rp-512 than for ll in 89.8958% of cases
# avg eff dim for grad_rp-512: 3.99224
# avg eff dim for ll: 2.31807
# Alg NN_kmeanspp-p_grad_rp-512_acs-rf-hyper-512 failed on step 9 of split 0 of task mlr_knn_rng_256x16: filling up with random samples because selection failed after n_selected = 219
# Alg NN_kmeanspp-p_grad_rp-512_acs-rf-hyper-512 failed on step 7 of split 0 of task fried_256x16: filling up with random samples because selection failed after n_selected = 194
# Total number of DBAL steps across all experiments: 331200
# Generating tables...
# Creating learning curve plots...
# Creating individual learning curve plots with subplots...
# Creating skewness plots...
# plot_skewness_ax: R^2 = 0.790182
# Creating correlation plots...
# Creating individual learning curve plots...
# Finished plotting
#
# Creating lcmd visualization...

# %% [markdown]
# ## Running custom configurations on the benchmark

# %% [markdown]
# If you want to run your own configurations on the benchmark, you may want to take a look at the code in `run_experiments.py`. Here, we will show a minimalistic example of how to run two custom benchmark configurations, which can run on a CPU in a few minutes. A few other files you may find helpful are:
# - `test_single_task.py` allows you to run a single BMDAL configuration on a single split of a single data set, for fast exploration.
# - `rename_algs.py` contains a few helper functions to modify/rename/remove saved results. It can be used for example if the names of some experiment results should be changed.

# %% [markdown]
# First, we need to specify a function that adds configurations to a runner object:

# %%
def add_custom_configs(runner, tasks):
    # some general configuration for the NN and active learning
    kwargs = dict(post_sigma=1e-2, maxdet_sigma=1e-2, weight_gain=0.2, bias_gain=0.2, lr=0.375, act='relu')
    # specific configurations
    runner.add(tasks, 1e-6, ModelTrainer(f'NN_random', selection_method='random',
                                             base_kernel='linear', kernel_transforms=[], **kwargs))
    runner.add(tasks, 4e-6, ModelTrainer(f'NN_lcmd-tp_grad_rp-512', selection_method='lcmd', sel_with_train=True,
                                             base_kernel='grad', kernel_transforms=[('rp', [512])], **kwargs))

# %% [markdown]
# Let us take this apart: We defined a function `add_custom_configs`, which takes a runner object and a list of tasks, the details of both do not need to concern us here. In this function, we first define a dictionary with common arguments for convenience. These arguments are as follows:
# - `post_sigma` is the $\sigma$ value for the posterior transformation, and is not needed for these two configurations.
# - `maxdet_sigma` is the $\sigma$ value for the MaxDet selection method, and is not needed for these two configurations.
# - `weight_gain` corresponds to $\sigma_w$ from the paper
# - `bias_gain` corresponds to $\sigma_b$ from the paper
# - `lr` is the initial learning rate (decayed linearly to zero)
# - `act` is the name of the activation function
#
# There are many more possible arguments which can be found by inspecting the code at `train.py` and `bmdal/algorithms.py`. For the configurations, we use the following arguments:
# - The values 1e-6 and 4e-6 are upper bound estimates for how much RAM (in GB) per train+pool sample will be used. These are relevant if you want to run as many experiments in parallel as possible while avoiding out-of-memory errors. Otherwise you can just use small values and limit the number of jobs per device (see below).
# - The first argument to ModelTrainer is the name of the configuration, in our case we start with NN followed by selection method (-mode), base kernel and kernel transformations. This particular naming scheme is sometimes exploited in our evaluation code (mainly for plotting), but you may use a different naming scheme.
# - The arguments `selection_method`, `base_kernel` and `kernel_transforms` correspond to the choices in our framework, and valid options are described in detail in `bmdal/algorithms.py`. For `NN_random`, the kernel has no influence on the results, hence we use the linear kernel since it triggers the least amount of computations.
# - The argument `sel_with_train` chooses between P-mode and TP-mode. Here we use TP-mode for LCMD, which is also the default value for LCMD, hence it would not have been necessary to specify `sel_with_train=True` here.
#
# Note that the configuration `NN_random` is simply the random selection baseline, and the configuration `NN_lcmd-tp_grad_rp-512` is the method suggested in our paper.

# %% [markdown]
# Next, we run these configurations. The meaning of the parameters will be explained below.

# %%
from run_experiments import run_experiments
from train import ModelTrainer
run_experiments(exp_name='relu_small', n_splits=2, add_configs_func=add_custom_configs, 
                batch_sizes_configs=[[64, 128]], task_descs=['64-128'], use_pool_for_normalization=True,
                max_jobs_per_device=4, n_train_initial=64, ds_names=['ct', 'kegg_undir_uci'], sequential_split=9)
# Out:
# Task ct has n_pool=41712, n_test=10700, n_features=379
# Task kegg_undir_uci has n_pool=50599, n_test=12921, n_features=27
# Running all configurations on split 0
# Start time: 2022-03-16 17:29:46
# Starting job 1/4 after 1s
# Starting job 2/4 after 1s
# Starting job 3/4 after 1s
# Starting job 4/4 after 1s
# Running NN_lcmd-tp_grad_rp-512 on split 0 of task kegg_undir_uci_64-128 on device cpu
# Running NN_random on split 0 of task kegg_undir_uci_64-128 on device cpu
# Running NN_random on split 0 of task ct_64-128 on device cpu
# Running NN_lcmd-tp_grad_rp-512 on split 0 of task ct_64-128 on device cpu
# ................................................................................................................................................................................................................................................................
# Test results: MAE=0.34011, RMSE=0.507062, MAXE=2.53953, q95=1.17227, q99=1.83336
#
#
# Performing AL step 1/2 with n_train=64, n_pool=41712, al_batch_size=64
# ................................................................................................................................................................................................................................................................
# Test results: MAE=0.34011, RMSE=0.507062, MAXE=2.53953, q95=1.17227, q99=1.83336
#
#
# Performing AL step 1/2 with n_train=64, n_pool=41712, al_batch_size=64
# ................................................................................................................................................................................................................................................................
# ................................................................................................................................................................................................................................................................
# Test results: MAE=0.491869, RMSE=0.922071, MAXE=10.8996, q95=1.43869, q99=4.19223
#
#
# Performing AL step 1/2 with n_train=64, n_pool=50599, al_batch_size=64
# Test results: MAE=0.491869, RMSE=0.922071, MAXE=10.8996, q95=1.43869, q99=4.19223
#
#
# Performing AL step 1/2 with n_train=64, n_pool=50599, al_batch_size=64
# ................................................................................................................................................................................................................................................................
# Test results: MAE=0.258021, RMSE=0.400956, MAXE=2.5322, q95=0.924099, q99=1.52103
#
#
# Performing AL step 2/2 with n_train=128, n_pool=41648, al_batch_size=128
# ................................................................................................................................................................................................................................................................
# Test results: MAE=0.264738, RMSE=0.397067, MAXE=2.30169, q95=0.867531, q99=1.50032
#
#
# Performing AL step 2/2 with n_train=128, n_pool=41648, al_batch_size=128
# ................................................................................................................................................................................................................................................................
# Test results: MAE=0.461253, RMSE=0.933182, MAXE=11.0417, q95=1.59126, q99=4.33526
#
#
# Performing AL step 2/2 with n_train=128, n_pool=50535, al_batch_size=128
# ................................................................................................................................................................................................................................................................
# Test results: MAE=0.429492, RMSE=0.83962, MAXE=10.6092, q95=1.69958, q99=3.49928
#
#
# Performing AL step 2/2 with n_train=128, n_pool=50535, al_batch_size=128
# ................................................................................................................................................................................................................................................................
# Test results: MAE=0.179103, RMSE=0.325031, MAXE=2.62553, q95=0.668155, q99=1.5139
#
#
# Finished running NN_random on split 0 of task ct_64-128 on device cpu
# ................................................................................................................................................................................................................................................................
# Test results: MAE=0.186181, RMSE=0.294652, MAXE=2.73553, q95=0.61273, q99=1.14099
#
#
# Finished running NN_lcmd-tp_grad_rp-512 on split 0 of task ct_64-128 on device cpu
# ................................................................................................................................................................................................................................................................
# Test results: MAE=0.373252, RMSE=0.856716, MAXE=10.739, q95=1.63433, q99=3.87395
#
#
# Finished running NN_random on split 0 of task kegg_undir_uci_64-128 on device cpu
# ................................................................................................................................................................................................................................................................
# Test results: MAE=0.235933, RMSE=0.525428, MAXE=5.8273, q95=1.19829, q99=2.19989
#
#
# Finished running NN_lcmd-tp_grad_rp-512 on split 0 of task kegg_undir_uci_64-128 on device cpu
# End time: 2022-03-16 17:34:20
# Total time: 4m33s
# Running all configurations on split 1
# Results already exist for NN_random on split 0 of task ct_64-128
# Results already exist for NN_random on split 0 of task kegg_undir_uci_64-128
# Results already exist for NN_lcmd-tp_grad_rp-512 on split 0 of task ct_64-128
# Results already exist for NN_lcmd-tp_grad_rp-512 on split 0 of task kegg_undir_uci_64-128
# Start time: 2022-03-16 17:34:20
# Starting job 1/4 after 1s
# Starting job 2/4 after 1s
# Starting job 3/4 after 1s
# Starting job 4/4 after 1s
# Running NN_lcmd-tp_grad_rp-512 on split 1 of task kegg_undir_uci_64-128 on device cpu
# Running NN_random on split 1 of task ct_64-128 on device cpu
# Running NN_random on split 1 of task kegg_undir_uci_64-128 on device cpu
# Running NN_lcmd-tp_grad_rp-512 on split 1 of task ct_64-128 on device cpu
# ................................................................................................................................................................................................................................................................
# ................................................................................................................................................................................................................................................................
# Test results: MAE=0.329674, RMSE=0.456344, MAXE=2.42349, q95=0.936505, q99=1.6017
#
#
# Performing AL step 1/2 with n_train=64, n_pool=41712, al_batch_size=64
# Test results: MAE=0.329674, RMSE=0.456344, MAXE=2.42349, q95=0.936505, q99=1.6017
#
#
# Performing AL step 1/2 with n_train=64, n_pool=41712, al_batch_size=64
# ................................................................................................................................................................................................................................................................
# Test results: MAE=0.380219, RMSE=0.902585, MAXE=10.6208, q95=2.02474, q99=3.8178
#
#
# Performing AL step 1/2 with n_train=64, n_pool=50599, al_batch_size=64
# ................................................................................................................................................................................................................................................................
# Test results: MAE=0.380219, RMSE=0.902585, MAXE=10.6208, q95=2.02474, q99=3.8178
#
#
# Performing AL step 1/2 with n_train=64, n_pool=50599, al_batch_size=64
# ................................................................................................................................................................................................................................................................
# Test results: MAE=0.222859, RMSE=0.357482, MAXE=2.51176, q95=0.784285, q99=1.45159
#
#
# Performing AL step 2/2 with n_train=128, n_pool=41648, al_batch_size=128
# ................................................................................................................................................................................................................................................................
# Test results: MAE=0.247811, RMSE=0.371816, MAXE=2.16033, q95=0.787072, q99=1.4485
#
#
# Performing AL step 2/2 with n_train=128, n_pool=41648, al_batch_size=128
# ................................................................................................................................................................................................................................................................
# Test results: MAE=0.416239, RMSE=0.839556, MAXE=9.89747, q95=1.58267, q99=3.21139
#
#
# Performing AL step 2/2 with n_train=128, n_pool=50535, al_batch_size=128
# ................................................................................................................................................................................................................................................................
# Test results: MAE=0.28811, RMSE=0.659412, MAXE=5.87151, q95=1.33919, q99=3.0144
#
#
# Performing AL step 2/2 with n_train=128, n_pool=50535, al_batch_size=128
# ................................................................................................................................................................................................................................................................
# Test results: MAE=0.196427, RMSE=0.342279, MAXE=2.7915, q95=0.738076, q99=1.45722
#
#
# Finished running NN_random on split 1 of task ct_64-128 on device cpu
# ................................................................................................................................................................................................................................................................
# Test results: MAE=0.174145, RMSE=0.268546, MAXE=2.39269, q95=0.532633, q99=1.03625
#
#
# Finished running NN_lcmd-tp_grad_rp-512 on split 1 of task ct_64-128 on device cpu
# ................................................................................................................................................................................................................................................................
# Test results: MAE=0.299052, RMSE=0.782394, MAXE=11.2726, q95=1.38686, q99=3.09939
#
#
# Finished running NN_random on split 1 of task kegg_undir_uci_64-128 on device cpu
# ................................................................................................................................................................................................................................................................
# Test results: MAE=0.241831, RMSE=0.503662, MAXE=4.88252, q95=1.0997, q99=2.21781
#
#
# Finished running NN_lcmd-tp_grad_rp-512 on split 1 of task kegg_undir_uci_64-128 on device cpu
# End time: 2022-03-16 17:39:13
# Total time: 4m53s

# %% [markdown]
# Here, the meaning of the parameters is as follows:
# - `exp_name` is the name of the subfolder that the results will be saved at. This can be used to group experiments together, for example we used separate groups for relu and silu experiments in our paper.
# - `n_splits` is the number of random splits that the configurations should be run on. The random splits will be run in order.
# - `add_configs_func` is the callback function to add the configurations.
# - `batch_sizes_configs` is a list of lists of batch sizes. In our case, we only have one batch size configuration, which is to acquire 64 samples in the first BMAL step and 128 samples in the second BMAL step. For experiments in our paper, we mostly used `batch_sizes_configs=[[256]*16]`.
# - `task_descs` is a corresponding list of suffixes for the task names. For example, here the data set `ct` combined with the batch size configuration `[64, 128]` will get the name `ct_64-128`.
# - `use_pool_for_normalization` specifies whether the dataset standardization should use statistics from the training and pool set or only from the training set. We used standardization only from the training set in our experiments, but especially for smaller initial training set sizes, it may be important to standardize also with the pool set.
# - `max_jobs_per_device` allows to specify a maximum number of jobs that are run in parallel on a single device (CPU or GPU). Fewer jobs may be executed in parallel if their estimated RAM usage (see above) would otherwise exceed the remaining RAM capacity (measured at the start of `run_experiments`).
# - `n_train_initial` specifies the initial training set size, which was 256 in our experiments.
# - `ds_names` specifies the names of the data sets that experiments should be run on. Possible names can be found in the data folder specified in `custom_paths.py`. By default, all 15 data sets from the benchmark are used.
# - `sequential_split` specifies the index of the random split for which `max_jobs_per_device=1` is used; the results from this split can then be used for runtime evaluation. By default, this is set to 9. Since we only use `n_splits=2` here, this case is not reached.
#
# Since the experiments above were run on a CPU, they took 5 minutes to complete, but this would be much faster on a GPU, especially with even higher `max_jobs_per_device`. If we ran this code again, it would notice that the results are already computed and would not recompute them.

# %% [markdown]
# Next, we want to evaluate the results. Unfortunately, we cannot directly use `run_evaluation.py` since its current implementation filters results by the suffix `256x16`, while our results use the suffix `64-128`. Therefore, we give a small example showing how to print a table for the results:

# %%
from evaluation.analysis import ExperimentResults, print_avg_results
results = ExperimentResults.load('relu_small')
print_avg_results(results, relative_to=None, filter_suffix='')
# Out:
# Averaged results across tasks:
# Results for metric mae:
# NN_lcmd-tp_grad_rp-512: -1.388 +- 0.035
# NN_random:              -1.256 +- 0.029
#
# Results for metric rmse:
# NN_lcmd-tp_grad_rp-512: -0.796 +- 0.029
# NN_random:              -0.598 +- 0.018
#
# Results for metric q95:
# NN_lcmd-tp_grad_rp-512: -0.050 +- 0.036
# NN_random:              0.089  +- 0.016
#
# Results for metric q99:
# NN_lcmd-tp_grad_rp-512: 0.611 +- 0.017
# NN_random:              0.838 +- 0.047
#
# Results for metric maxe:
# NN_lcmd-tp_grad_rp-512: 1.370 +- 0.070
# NN_random:              1.667 +- 0.007

# %% [markdown]
# We can also print results on individual data sets:

# %%
from evaluation.analysis import print_all_task_results
print_all_task_results(results)
# Out:
# Results for task ct_64-128:
# Results for metric mae:
# NN_random:              -1.551 +- 0.010
# NN_lcmd-tp_grad_rp-512: -1.538 +- 0.023
#
# Results for metric rmse:
# NN_lcmd-tp_grad_rp-512: -1.112 +- 0.028
# NN_random:              -1.035 +- 0.011
#
# Results for metric q95:
# NN_lcmd-tp_grad_rp-512: -0.375 +- 0.042
# NN_random:              -0.257 +- 0.011
#
# Results for metric q99:
# NN_lcmd-tp_grad_rp-512: 0.236 +- 0.023
# NN_random:              0.396 +- 0.015
#
# Results for metric maxe:
# NN_lcmd-tp_grad_rp-512: 0.871 +- 0.035
# NN_random:              0.960 +- 0.009
#
#
#
#
# Results for task kegg_undir_uci_64-128:
# Results for metric mae:
# NN_lcmd-tp_grad_rp-512: -1.238 +- 0.066
# NN_random:              -0.961 +- 0.057
#
# Results for metric rmse:
# NN_lcmd-tp_grad_rp-512: -0.480 +- 0.050
# NN_random:              -0.161 +- 0.035
#
# Results for metric q95:
# NN_lcmd-tp_grad_rp-512: 0.275 +- 0.057
# NN_random:              0.435 +- 0.030
#
# Results for metric q99:
# NN_lcmd-tp_grad_rp-512: 0.985 +- 0.025
# NN_random:              1.280 +- 0.092
#
# Results for metric maxe:
# NN_lcmd-tp_grad_rp-512: 1.870 +- 0.136
# NN_random:              2.373 +- 0.011

# %% [markdown]
# The results are saved using the folder structure `results_folder/exp_name/task_name/alg_name/split_idx/results.json`. For example, you can view the tasks we ran experiments on as follows:

# %%
from pathlib import Path
import custom_paths
os.listdir(Path(custom_paths.get_results_path()) / 'relu_small')
# Out:
# ['ct_64-128', 'kegg_undir_uci_64-128']

# %% [markdown]
# ## Implementing your own methods

# %% [markdown]
# If you want to go beyond using our already implemented combinations of selection methods, kernels and kernel transformations, you have to make some modifications to the code such that your method can be used as above. Depending on how different your method is, we suggest three ways of including it:
# - If your method fits to our framework and simply provides new selection methods, kernels and/or kernel transformations, we suggest to extend `BatchSelector.select()` in `bmdal/algorithms.py` such that it can use your new component(s) given the corresponding configuration string(s).
# - If your method is a different BMDAL method that does not fit into our framework but does not require to modify the NN training process, you can modify the BMDAL part in `ModelTrainer.__call__()` in `train.py` such that it can call your method. While you could realize this by passing a custom BMDAL class or factory method directly to ModelTrainer, you should note that arguments to ModelTrainer are currently serialized to a JSON file, which is why we prefer using native data types like strings as arguments to ModelTrainer. This serialization of arguments to a JSON file can be helpful for example for automatically generating figure captions later on.
# - If you also want to modify the NN training process, you may want to change other code in ModelTrainer or replace it by your own custom class. Note that the NN model creation itself can be customized in ModelTrainer through the `create_model` argument.
